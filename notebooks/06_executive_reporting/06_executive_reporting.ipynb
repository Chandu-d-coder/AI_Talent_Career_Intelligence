# %% [markdown]
# # Executive Reporting
#
# ## AI Talent & Career Intelligence Platform
#
# ### Executive Dashboard and Strategic Workforce Report
#
# **Project Phase:** Phase 5 – Executive Reporting
#
# **Prepared By:** Chandra Saikumar
#
# **Project:** AI Talent & Career Intelligence Platform
#
# ---
#
# ### Project Objective
#
# This executive report consolidates insights generated from comprehensive workforce analytics performed on a global AI employment dataset containing over **90,000 records**.
#
# The report supports decision-making in:
#
# - Workforce Compensation
# - Career Growth
# - Workforce Risk
# - Talent Market
# - Employee Experience
# - Recruitment Performance

# %% [markdown]
# # Executive Summary
#
# This report presents a comprehensive workforce intelligence assessment of the global AI job market.
#
# ### Major Findings
#
# - Experience is the strongest driver of salary growth.
# - Career progression depends more on promotion efficiency than experience alone.
# - Job security is driven more by layoff risk than automation.
# - AI hiring demand remains consistently high.
# - Employee satisfaction is strongly influenced by salary, job security, and work-life balance.
# - Recruitment success depends on multiple organizational factors.
#
# Engineered workforce metrics extend traditional HR analytics and improve executive decision-making.

# %% [markdown]
# # Dataset Overview
#
# ### Dataset Characteristics
#
# - Total Records: 90,000
# - Total Features: 35
# - Countries: 12
# - Industries: 10
# - AI Specializations: 8
# - Experience Levels: 4
# - Experience Range: 0–19 Years
#
# ### Intelligence Domains
#
# - Salary Intelligence
# - Career Growth Intelligence
# - Workforce Risk Intelligence
# - Talent Market Intelligence
# - Employee Experience Intelligence
# - Recruitment Intelligence

# %%
import warnings
import platform
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Configure execution environment and suppress warnings
warnings.filterwarnings("ignore")

# Optimize pandas display configurations for comprehensive data inspection.
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", None)

# Log framework metadata and verification metrics.

print("Environment Information")
print("-" * 22)
print(f"Python Version : {platform.python_version()}")
print(f"Pandas Version : {pd.__version__}")
print(f"NumPy Version  : {np.__version__}")
# Out:
# Environment Information
# ----------------------
# Python Version : 3.14.6
# Pandas Version : 3.0.3
# NumPy Version  : 2.4.6

# %%
# Load target dataset

DATA_PATH = "../../data/processed/cleaned_ai_jobs.csv"
df = pd.read_csv(DATA_PATH)
print("\nDataset Loaded Successfully")

# Execute descriptive matrix shape verification.

print("\nDataset Shape")
print("-" * 16)

total_rows, total_columns = df.shape

print(f"Rows    : {total_rows:,}")
print(f"Columns : {total_columns}")
print("-" * 16)

# Display a quick preview of the dataset schema.

display(df.head())
# Out:
# Dataset Loaded Successfully
#
# Dataset Shape
# ----------------
# Rows    : 90,000
# Columns : 35
# ----------------
#    id  country                   job_role       ai_specialization  \
# 0   1      UAE  Machine Learning Engineer  Reinforcement Learning
# 1   2      USA                AI Engineer                     LLM
# 2   3   Brazil         Research Scientist               Analytics
# 3   4    India       AI Software Engineer         Computer Vision
# 4   5  Germany  Machine Learning Engineer         Computer Vision
#
#   experience_level  experience_years  salary_usd  bonus_usd  \
# 0            Entry                 0       66465       5395
# 1            Entry                 1       75507      11713
# 2            Entry                 0       41660       5268
# 3           Senior                 6       43268       7975
# 4            Entry                 0       69119       4758
#
#   education_required    industry company_size  interview_rounds  year  \
# ...

# %%
# Executive KPI Dashboard

executive_kpis = pd.DataFrame({
    "Metric": [
        "Total Records","Countries","Industries","AI Specializations",
        "Average Salary (USD)","Maximum Salary (USD)","Average Bonus (USD)",
        "Average Career Growth","Average Job Security",
        "Average Employee Satisfaction","Average Offer Acceptance",
        "Average Job Openings"
    ],
    "Value": [
        len(df),
        df["country"].nunique(),
        df["industry"].nunique(),
        df["ai_specialization"].nunique(),
        round(df["salary_usd"].mean(),2),
        round(df["salary_usd"].max(),2),
        round(df["bonus_usd"].mean(),2),
        round(df["career_growth_score"].mean(),2),
        round(df["job_security_score"].mean(),2),
        round(df["employee_satisfaction"].mean(),2),
        round(df["offer_acceptance_rate"].mean(),2),
        round(df["job_openings"].mean(),2)
    ]
})

executive_kpis
# Out:
#                            Metric      Value
# 0                   Total Records   90000.00
# 1                       Countries      12.00
# 2                      Industries      10.00
# 3              AI Specializations       8.00
# 4            Average Salary (USD)   96546.25
# 5            Maximum Salary (USD)  300622.00
# 6             Average Bonus (USD)   13028.42
# 7           Average Career Growth      57.20
# 8            Average Job Security      75.56
# 9   Average Employee Satisfaction      72.73
# 10       Average Offer Acceptance      75.01
# 11           Average Job Openings      17.52

# %% [markdown]
# ## Chart 1: Executive KPI Dashboard

# %%
kpi_values = {
    "Salary": df["salary_usd"].mean(),
    "Career Growth": df["career_growth_score"].mean(),
    "Job Security": df["job_security_score"].mean(),
    "Employee Satisfaction": df["employee_satisfaction"].mean(),
    "Offer Acceptance": df["offer_acceptance_rate"].mean(),
    "Skill Demand": df["skill_demand_score"].mean()
}

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(
    x=list(kpi_values.keys()),
    y=list(kpi_values.values()),
    color="steelblue",
    ax=ax
)

ax.set_title("Executive Workforce KPI Dashboard", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("")
ax.set_ylabel("Average Score")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart 2: Global Workforce Distribution

# %%
fig, ax = plt.subplots(figsize=(12,6))

sns.countplot(
    data=df,
    x="experience_level",
    order=["Entry","Mid","Senior","Lead"],
    color="seagreen",
    ax=ax
)

ax.set_title("Global AI Workforce Distribution by Experience Level", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Experience Level")
ax.set_ylabel("Number of Professionals")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart 3: AI Workforce by Country

# %%
country_counts = df["country"].value_counts().reset_index()
country_counts.columns = ["country","count"]

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(
    data=country_counts,
    x="count",
    y="country",
    color="mediumpurple",
    ax=ax
)

ax.set_title("AI Workforce Distribution by Country", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Number of Professionals")
ax.set_ylabel("Country")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Executive Dashboard Summary
#
# ### Key Observations
#
# - The dataset represents a balanced global AI workforce.
# - All major AI experience levels are represented.
# - Compensation, career growth, workforce stability, employee experience, and recruitment performance provide a holistic view of workforce health.
# - These KPIs establish the foundation for strategic workforce planning and executive decision-making.

# %% [markdown]
# # Salary Intelligence Summary
#
# ## Executive Overview
#
# Salary Intelligence analysis examined global compensation patterns across countries, industries, AI specializations, education levels, and experience levels.
#
# The analysis confirms that professional experience remains the strongest determinant of salary growth, while country and AI specialization also contribute significantly to compensation differences.
#
# Organizations seeking to attract and retain AI talent should prioritize competitive compensation structures alongside clear career progression pathways.

# %% [markdown]
# ## Executive Highlights
#
# ### Major Findings
#
# - Lead professionals receive the highest average salaries.
# - Salary consistently increases with years of experience.
# - The USA offers the highest average AI compensation.
# - Emerging AI domains such as LLM and Generative AI remain among the highest-paying specializations.
# - Education level has relatively limited influence compared to professional experience.
# - Bonus compensation closely follows salary growth.
#
# ### Business Impact
#
# Organizations should maintain market-aligned salary structures to improve talent acquisition and retention while investing in high-demand AI specializations.

# %%
salary_country = (
    df.groupby("country")["salary_usd"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=salary_country,
    x="salary_usd",
    y="country",
    color="steelblue",
    ax=ax
)

ax.set_title("Executive Salary Overview by Country", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Average Salary (USD)")
ax.set_ylabel("Country")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Career Growth Intelligence Summary
#
# ## Executive Overview
#
# Career Growth Intelligence evaluated promotion speed, career growth scores, salary percentile, and workforce progression.
#
# The findings indicate that promotion speed differentiates career progression more effectively than career growth scores, while AI specialization and experience significantly influence long-term advancement.
#
# Organizations should build structured promotion frameworks supported by continuous learning and technical development.

# %% [markdown]
# ## Executive Highlights
#
# ### Major Findings
#
# - Promotion Speed increases consistently with experience.
# - Career Growth Scores remain relatively stable across workforce segments.
# - LLM and Generative AI specialists demonstrate stronger long-term career opportunities.
# - Professional specialization influences promotion opportunities more than geographic location.
# - Engineered career metrics successfully identify high-potential professionals.
#
# ### Business Impact
#
# Career development strategies should emphasize skill progression, promotion transparency, and technical specialization rather than tenure alone.

# %%
promotion_summary = (
    df.groupby("experience_level")["promotion_speed"]
    .mean()
    .reindex(["Entry", "Mid", "Senior", "Lead"])
    .reset_index()
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    data=promotion_summary,
    x="experience_level",
    y="promotion_speed",
    color="seagreen",
    ax=ax
)

ax.set_title("Executive Promotion Speed Overview", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Experience Level")
ax.set_ylabel("Promotion Speed")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Workforce Risk Intelligence Summary
#
# ## Executive Overview
#
# Workforce Risk Intelligence analyzed employment stability using Job Security, Layoff Risk, Automation Risk, and AI Adoption.
#
# The results indicate that workforce stability depends primarily on organizational resilience and employee experience rather than automation alone.
#
# Senior professionals consistently demonstrate stronger employment stability across industries.

# %% [markdown]
# ## Executive Highlights
#
# ### Major Findings
#
# - Job Security increases significantly with experience.
# - Layoff Risk is the strongest predictor of workforce stability.
# - AI Adoption has limited direct impact on Job Security.
# - Employee Satisfaction positively contributes to workforce resilience.
# - Technology-driven organizations maintain strong workforce stability.
#
# ### Business Impact
#
# Organizations should invest in employee retention, internal career development, and workforce planning to strengthen long-term organizational resilience.

# %%
job_security_summary = (
    df.groupby("experience_level")["job_security_score"]
    .mean()
    .reindex(["Entry", "Mid", "Senior", "Lead"])
    .reset_index()
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    data=job_security_summary,
    x="experience_level",
    y="job_security_score",
    color="indianred",
    ax=ax
)

ax.set_title("Executive Job Security Overview", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Experience Level")
ax.set_ylabel("Job Security Score")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Executive Summary of Phase 4
#
# The Workforce Analytics phase successfully transformed raw workforce data into actionable business intelligence across six strategic domains.
#
# ### Key Outcomes
#
# - Identification of global salary patterns and compensation drivers.
# - Analysis of career progression across AI roles and experience levels.
# - Assessment of workforce stability using job security and layoff risk indicators.
# - Evaluation of global AI hiring demand and market competitiveness.
# - Measurement of employee experience through satisfaction and work-life balance metrics.
# - Analysis of recruitment effectiveness using offer acceptance and hiring efficiency.
#
# Together, these findings provide a comprehensive understanding of the global AI workforce and support evidence-based workforce planning, talent management, and organizational decision-making.

# %% [markdown]
# # Talent Market Intelligence Summary
#
# ## Executive Overview
#
# Talent Market Intelligence examined global hiring demand, skill demand, job openings, recruitment competitiveness, and market opportunities across the AI industry.
#
# The analysis indicates that AI talent demand remains consistently strong across countries and industries, while emerging AI specializations continue to drive recruitment demand. Organizations increasingly compete for professionals possessing advanced AI capabilities, particularly in high-growth technical domains.
#
# The engineered **Talent Demand Index** provides a holistic view of market attractiveness by combining hiring demand, AI adoption, and workforce opportunity indicators.

# %% [markdown]
# ## Executive Highlights
#
# ### Major Findings
#
# - AI hiring demand remains consistently high across global markets.
# - LLM, NLP, Generative AI, and Reinforcement Learning continue to attract strong employer demand.
# - AI Software Engineers and Machine Learning Engineers experience the highest recruitment activity.
# - Skill Demand is a stronger indicator of market opportunity than geographic location.
# - Healthcare, Technology, and Finance remain among the largest AI hiring industries.
#
# ### Business Impact
#
# Organizations should continuously invest in workforce development and proactive talent acquisition strategies to remain competitive in rapidly evolving AI markets.

# %%
talent_summary=(
    df.groupby("ai_specialization")["skill_demand_score"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(data=talent_summary,
            x="skill_demand_score",
            y="ai_specialization",
            color="steelblue",
            ax=ax)

ax.set_title("Executive AI Skill Demand Overview", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Average Skill Demand Score")
ax.set_ylabel("AI Specialization")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Employee Experience Intelligence Summary
#
# ## Executive Overview
#
# Employee Experience Intelligence evaluated workforce wellbeing using employee satisfaction, work-life balance, working hours, vacation policies, and company ratings.
#
# The analysis demonstrates that employee satisfaction is primarily driven by compensation, job security, and healthy work-life balance. Flexible work arrangements alone do not significantly improve employee experience without supportive organizational practices.
#
# The Employee Experience Index developed in this project enables organizations to monitor workforce wellbeing using multiple performance dimensions rather than isolated satisfaction metrics.

# %% [markdown]
# ## Executive Highlights
#
# ### Major Findings
#
# - Employee Satisfaction remains consistently high across the AI workforce.
# - Salary and Job Security are the strongest contributors to employee satisfaction.
# - Longer working hours reduce employee wellbeing.
# - Work-Life Balance positively influences long-term employee engagement.
# - Company Rating alone has limited influence on employee satisfaction.
#
# ### Business Impact
#
# Organizations should improve employee experience by balancing competitive compensation, career stability, workload management, and employee wellbeing initiatives.

# %%
employee_summary=(
    df.groupby("work_mode")["employee_satisfaction"]
    .mean()
    .reset_index()
)

fig, ax = plt.subplots(figsize=(10,6))

sns.barplot(data=employee_summary,
            x="work_mode",
            y="employee_satisfaction",
            color="seagreen",
            ax=ax)

ax.set_title("Executive Employee Satisfaction Overview", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Work Mode")
ax.set_ylabel("Employee Satisfaction")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Recruitment Intelligence Summary
#
# ## Executive Overview
#
# Recruitment Intelligence examined offer acceptance, recruitment efficiency, hiring difficulty, and candidate attraction across the AI workforce.
#
# The analysis shows that AI recruitment remains healthy across industries, with consistently high offer acceptance rates. Recruitment outcomes depend on multiple organizational factors rather than compensation alone, emphasizing the importance of employer branding and candidate experience.
#
# The engineered Recruitment Success Index and Candidate Attraction Score provide organizations with practical measures for evaluating hiring performance.

# %% [markdown]
# ## Executive Highlights
#
# ### Major Findings
#
# - Offer Acceptance remains consistently high across countries and industries.
# - Salary alone does not determine candidate acceptance.
# - Employer attractiveness contributes more to recruitment success than compensation alone.
# - AI recruitment remains competitive despite increasing market demand.
# - Efficient recruitment processes improve hiring effectiveness.
#
# ### Business Impact
#
# Organizations should strengthen employer branding, simplify recruitment workflows, and enhance candidate experience to improve long-term hiring success.

# %%
offer_summary=(
    df.groupby("country")["offer_acceptance_rate"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(data=offer_summary,
            x="offer_acceptance_rate",
            y="country",
            color="mediumpurple",
            ax=ax)

ax.set_title("Executive Offer Acceptance Overview", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Offer Acceptance Rate (%)")
ax.set_ylabel("Country")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Cross-Module Executive Insights
#
# The six workforce intelligence modules collectively reveal several strategic patterns across the global AI workforce.
#
# ## Cross-Module Findings
#
# ### Compensation
# Professional experience remains the strongest driver of salary growth, while AI specialization further differentiates compensation.
#
# ### Career Development
# Promotion speed provides a more accurate measure of career progression than career growth scores alone.
#
# ### Workforce Stability
# Layoff Risk has a substantially greater influence on workforce stability than Automation Risk.
#
# ### Talent Market
# Emerging AI technologies such as LLMs, NLP, MLOps, and Generative AI continue to dominate hiring demand.
#
# ### Employee Experience
# Employee satisfaction depends primarily on salary, job security, and work-life balance rather than work location.
#
# ### Recruitment
# Successful recruitment depends on employer attractiveness, recruitment efficiency, and overall employee value proposition rather than compensation alone.
#
# ## Overall Executive Insight
#
# Organizations that simultaneously invest in competitive compensation, career development, workforce stability, employee wellbeing, and recruitment excellence establish stronger long-term competitive advantages in the global AI talent market.

# %%
executive_scores={
    "Salary":df["salary_percentile"].mean(),
    "Career Growth":df["career_growth_score"].mean(),
    "Job Security":df["job_security_score"].mean(),
    "Skill Demand":df["skill_demand_score"].mean(),
    "Employee Satisfaction":df["employee_satisfaction"].mean(),
    "Offer Acceptance":df["offer_acceptance_rate"].mean()
}

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(x=list(executive_scores.keys()),
            y=list(executive_scores.values()),
            color="darkorange",
            ax=ax)

ax.set_title("Overall Executive Workforce Performance", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("")
ax.set_ylabel("Average Score")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()
plt.tight_layout()
plt.show()

# %% [markdown]
# # Strategic Business Recommendations
#
# Based on the comprehensive workforce intelligence analysis, the following strategic recommendations are proposed for organizations seeking to strengthen their AI workforce.
#
# ## For Executive Leadership
#
# - Develop long-term AI workforce strategies aligned with business objectives.
# - Invest continuously in emerging AI technologies and high-demand technical skills.
# - Use workforce analytics as a foundation for strategic decision-making.
# - Establish data-driven compensation and promotion frameworks.
#
# ## For Human Resources
#
# - Improve employee retention through structured career development programs.
# - Build transparent promotion pathways based on measurable performance.
# - Monitor employee wellbeing using multiple workforce indicators.
# - Regularly benchmark compensation against market trends.
#
# ## For Talent Acquisition Teams
#
# - Strengthen employer branding to improve recruitment success.
# - Reduce unnecessary interview stages to improve candidate experience.
# - Build proactive talent pipelines for emerging AI domains.
# - Prioritize technical competency alongside cultural fit during recruitment.
#
# ## For Business Leaders
#
# - Align workforce planning with organizational growth objectives.
# - Invest in continuous employee learning and AI upskilling.
# - Monitor workforce stability using predictive workforce metrics.
# - Use workforce intelligence to optimize organizational performance.
#
# ## For AI Professionals
#
# - Develop expertise in high-demand AI specializations such as LLMs, NLP, MLOps, and Generative AI.
# - Continuously improve both technical and business skills.
# - Evaluate employers based on long-term career growth and organizational stability.
# - Build practical project experience to remain competitive in the AI job market.

# %% [markdown]
# # Future Outlook
#
# The global Artificial Intelligence workforce will continue to evolve rapidly over the coming years.
#
# Organizations that successfully combine workforce intelligence, employee development, and strategic recruitment will maintain stronger competitive advantages.
#
# ### Future Enhancements
#
# - Machine Learning salary prediction models
# - Employee attrition prediction
# - Hiring demand forecasting
# - AI skill recommendation systems
# - Workforce optimization models
# - Interactive Power BI dashboards
# - Streamlit web applications
# - Real-time workforce monitoring
# - Cloud-based workforce intelligence platforms
# - Generative AI-powered HR assistants
#
# These enhancements can transform descriptive workforce analytics into predictive and prescriptive business intelligence solutions.

# %% [markdown]
# # Project Achievements
#
# ## Project Summary
#
# This project successfully transformed a large-scale AI workforce dataset into meaningful business intelligence through systematic data analytics.
#
# ### Project Statistics
#
# - Dataset Size: 90,000 Records
# - Features Analyzed: 35
# - Intelligence Modules: 6
# - Analytics Techniques: 8+
# - Business Findings Generated: 100+
# - Executive Dashboards: Multiple
# - Professional Visualizations: 60+
# - Engineered Workforce Metrics: 15+
#
# ### Technologies Used
#
# - Python
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Jupyter Notebook
# - Git
# - GitHub
#
# ### Analytics Skills Demonstrated
#
# - Data Cleaning
# - Exploratory Data Analysis
# - Statistical Analysis
# - Business Intelligence
# - Feature Engineering
# - Data Visualization
# - Executive Reporting
# - Strategic Decision Support

# %% [markdown]
# # Final Conclusion
#
# This project demonstrates the complete lifecycle of a professional workforce analytics solution, beginning with raw data exploration and ending with executive-level business recommendations.
#
# Across six intelligence domains, the analysis identified key workforce patterns related to compensation, career progression, workforce stability, talent demand, employee experience, and recruitment performance.
#
# The engineered workforce metrics developed throughout the project extend traditional descriptive analytics by providing additional perspectives on organizational performance and workforce health.
#
# The findings generated through this project can assist organizations in improving strategic workforce planning, employee retention, talent acquisition, organizational resilience, and long-term business growth.
#
# Overall, this project illustrates how data analytics can be be transformed into practical business intelligence capable of supporting executive decision-making within the rapidly evolving global AI industry.

# %% [markdown]
# # Thank You
#
# ## AI Talent & Career Intelligence Platform
#
# ### End of Executive Report
#
# **Prepared by**
#
# **Chandra Saikumar**
#
# Master of Computer Applications (MCA)
#
# Aspiring AI Engineer
#
# ---
#
# This project was developed as a professional portfolio demonstrating practical skills in:
#
# - Data Analytics
# - Business Intelligence
# - Workforce Analytics
# - Data Visualization
# - Executive Reporting
# - Python Data Ecosystem
#
# Thank you for reviewing this project.
