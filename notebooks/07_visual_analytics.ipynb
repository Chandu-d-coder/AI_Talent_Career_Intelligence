# %% [markdown]
# # 01 Salary Visuals

# %% [markdown]
# ## Salary Intelligence Visual Analytics
#
# ## Level 1 : Distribution Analytics
#
# Goal: Understand how salary and compensation are distributed across the AI workforce.
#
# This level should contain 5 charts.

# %%
import platform
import numpy as np
import pandas as pd
import matplotlib
from matplotlib.ticker import StrMethodFormatter
import matplotlib.pyplot as plt
import seaborn as sns

# Optimize pandas display configurations for comprehensive data inspection.
pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", None)

# Log framework metadata and verification metrics.
print("Environment Information")
print("-" * 22)
print(f"Python Version     : {platform.python_version()}")
print(f"Pandas Version     : {pd.__version__}")
print(f"NumPy Version      : {np.__version__}")
print(f"Matplotlib Version : {matplotlib.__version__}")
print(f"Seaborn Version    : {sns.__version__}")
# Out:
# Environment Information
# ----------------------
# Python Version     : 3.14.6
# Pandas Version     : 3.0.3
# NumPy Version      : 2.4.6
# Matplotlib Version : 3.11.0
# Seaborn Version    : 0.13.2

# %%
# Load target dataset

DATA_PATH = "../data/processed/cleaned_ai_jobs.csv"
df = pd.read_csv(DATA_PATH)
print("\nDataset Loaded Successfully")

# Execute descriptive matrix shape verification.

print("\nDataset Shape")
print("-" * 16)

total_rows, total_columns = df.shape

print(f"Rows    : {total_rows:,}")
print(f"Columns : {total_columns}")
print("-" * 16)

# Display a quick preview of the dataset schema.

display(df.head())
# Out:
# Dataset Loaded Successfully
#
# Dataset Shape
# ----------------
# Rows    : 90,000
# Columns : 35
# ----------------
#    id  country                   job_role       ai_specialization  \
# 0   1      UAE  Machine Learning Engineer  Reinforcement Learning
# 1   2      USA                AI Engineer                     LLM
# 2   3   Brazil         Research Scientist               Analytics
# 3   4    India       AI Software Engineer         Computer Vision
# 4   5  Germany  Machine Learning Engineer         Computer Vision
#
#   experience_level  experience_years  salary_usd  bonus_usd  \
# 0            Entry                 0       66465       5395
# 1            Entry                 1       75507      11713
# 2            Entry                 0       41660       5268
# 3           Senior                 6       43268       7975
# 4            Entry                 0       69119       4758
#
#   education_required    industry company_size  interview_rounds  year  \
# ...

# %%
from pathlib import Path

# Root Visualization Directory
VISUALIZATION_DIR = Path("../visualizations")

# Create Required Subdirectories
subfolders = [
    "01_salary_intelligence",
    "02_career_growth",
    "03_workforce_risk",
    "04_talent_market",
    "05_employee_experience",
    "06_recruitment",
    "07_executive_dashboard"
]

for folder in subfolders:
    (VISUALIZATION_DIR / folder).mkdir(parents=True, exist_ok=True)

print("\nVisualization folders created successfully.")
# Out:
# Visualization folders created successfully.

# %%
# Create the figure and axes.
fig, ax = plt.subplots(figsize=(15, 7), dpi=150)

# Apply a clean visualization theme.
sns.set_theme(
    style="whitegrid",
    context="notebook",
    font="DejaVu Sans"
)

# Plot the salary distribution.
sns.histplot(
    data=df,
    x="salary_usd",
    bins="fd",
    kde=True,
    stat="count",
    color="#4C72B0",
    edgecolor="white",
    linewidth=0.8,
    alpha=0.90,
    line_kws={
        "linewidth": 2.5,
        "color": "#1F4E79"
    },
    ax=ax
)

# Add a reference line for the median salary.
median_salary = df["salary_usd"].median()

ax.axvline(
    median_salary,
    color="#C44E52",
    linestyle="--",
    linewidth=2
)

# Configure the chart title and axis labels.
ax.set_title(
    "Distribution of Annual Salaries Across AI Job Records",
    fontsize=18,
    fontweight="bold",
    pad=20
)

ax.set_xlabel(
    "Annual Salary (USD)",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

ax.set_ylabel(
    "Number of Job Records",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

# Format the x-axis as currency.
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.0f}"))

# Format tick labels.
ax.tick_params(
    axis="both",
    labelsize=11
)

# Improve grid styling.
ax.grid(
    axis="y",
    linestyle="--",
    linewidth=0.8,
    alpha=0.35
)

ax.grid(
    axis="x",
    visible=False
)

# Remove unnecessary spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Optimize layout.
plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "01_salary_distribution.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

# Display the visualization.
plt.show()

plt.close(fig)

# %%
# Configure visualization theme.
sns.set_theme(
    style="whitegrid",
    context="notebook",
    font_scale=1.05
)

# Create figure and axes.
fig, ax = plt.subplots(figsize=(15, 7), dpi=150)

# Plot bonus distribution.
sns.histplot(
    data=df,
    x="bonus_usd",
    bins="fd",
    stat="count",
    kde=True,
    color="#4C72B0",
    edgecolor="white",
    linewidth=0.7,
    alpha=0.90,
    line_kws={"linewidth": 2.2},
    ax=ax
)

# Calculate the median bonus.
median_bonus = df["bonus_usd"].median()

# Add a reference line for the median.
ax.axvline(
    median_bonus,
    color="#D62728",
    linestyle="--",
    linewidth=2
)

# Configure the chart title and axis labels.
ax.set_title(
    "Distribution of Annual Bonus Across AI Job Records",
    fontsize=18,
    fontweight="bold",
    pad=20
)

ax.set_xlabel(
    "Annual Bonus (USD)",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

ax.set_ylabel(
    "Number of Job Records",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

# Format the x-axis as currency.
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.0f}"))

# Format tick labels.
ax.tick_params(
    axis="both",
    labelsize=11
)

# Improve grid styling.
ax.grid(
    axis="y",
    linestyle="--",
    linewidth=0.8,
    alpha=0.35
)

ax.grid(
    axis="x",
    visible=False
)

# Remove unnecessary spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Optimize layout.
fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "02_bonus_distribution.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

# Display the visualization.
plt.show()

plt.close(fig)

# %%
# Create total compensation feature.
df["total_compensation"] = df["salary_usd"] + df["bonus_usd"]

# Configure visualization theme.
sns.set_theme(
    style="whitegrid",
    context="notebook",
    font_scale=1.05
)

# Calculate the median total compensation.
median_compensation = df["total_compensation"].median()

# Create figure and axes.
fig, ax = plt.subplots(figsize=(15, 7), dpi=150)

# Plot total compensation distribution.
sns.histplot(
    data=df,
    x="total_compensation",
    bins="fd",
    kde=True,
    stat="count",
    color="#4C72B0",
    edgecolor="white",
    linewidth=0.7,
    alpha=0.90,
    line_kws={"linewidth": 2.2},
    ax=ax
)

# Add a reference line for the median.
ax.axvline(
    median_compensation,
    color="#D62728",
    linestyle="--",
    linewidth=2
)

# Configure the chart title and axis labels.
ax.set_title(
    "Distribution of Total Compensation Across AI Job Records",
    fontsize=18,
    fontweight="bold",
    pad=20
)

ax.set_xlabel(
    "Total Compensation (USD)",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

ax.set_ylabel(
    "Number of Job Records",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

# Format the x-axis as currency.
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.0f}"))

# Format tick labels.
ax.tick_params(
    axis="both",
    labelsize=11
)

# Improve grid styling.
ax.grid(
    axis="y",
    linestyle="--",
    linewidth=0.8,
    alpha=0.35
)

ax.grid(
    axis="x",
    visible=False
)

# Remove unnecessary spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)

# Optimize layout.
fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "03_total_compensation_distribution.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %%
# Configure visualization theme.
sns.set_theme(
    style="whitegrid",
    context="notebook",
    font_scale=1.05
)

# Calculate the mean salary.
mean_salary = df["salary_usd"].mean()

# Create figure and axes.
fig, ax = plt.subplots(figsize=(15, 3.8), dpi=150)

# Plot salary distribution.
sns.boxplot(
    data=df,
    x="salary_usd",
    width=0.45,
    color="#4C72B0",
    linewidth=1.2,
    flierprops={
        "marker": "o",
        "markersize": 4,
        "markerfacecolor": "#D62728",
        "markeredgecolor": "white",
        "alpha": 0.65
    },
    ax=ax
)

# Add a reference line for the mean.
ax.axvline(
    mean_salary,
    color="#2CA02C",
    linestyle="--",
    linewidth=2
)

# Configure the chart title and axis labels.
ax.set_title(
    "Salary Distribution and Outlier Detection",
    fontsize=18,
    fontweight="bold",
    pad=20
)

ax.set_xlabel(
    "Annual Salary (USD)",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

ax.set_ylabel("")

# Format the x-axis as currency.
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.0f}"))

# Format tick labels.
ax.tick_params(
    axis="x",
    labelsize=11
)

# Improve grid styling.
ax.grid(
    axis="x",
    linestyle="--",
    linewidth=0.8,
    alpha=0.35
)

ax.grid(
    axis="y",
    visible=False
)

# Remove unnecessary spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

# Optimize layout.
fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "04_salary_boxplot.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %%
# Configure visualization theme.
sns.set_theme(
    style="whitegrid",
    context="notebook",
    font_scale=1.05
)

# Calculate the mean bonus.
mean_bonus = df["bonus_usd"].mean()

# Create figure and axes.
fig, ax = plt.subplots(figsize=(15, 3.8), dpi=150)

# Plot bonus distribution.
sns.boxplot(
    data=df,
    x="bonus_usd",
    width=0.45,
    color="#8E63CE",
    linewidth=1.2,
    flierprops={
        "marker": "o",
        "markersize": 4,
        "markerfacecolor": "#D62728",
        "markeredgecolor": "white",
        "alpha": 0.65
    },
    ax=ax
)

# Add a reference line for the mean.
ax.axvline(
    mean_bonus,
    color="#2CA02C",
    linestyle="--",
    linewidth=2
)

# Configure the chart title and axis labels.
ax.set_title(
    "Bonus Distribution and Outlier Detection",
    fontsize=18,
    fontweight="bold",
    pad=20
)

ax.set_xlabel(
    "Annual Bonus (USD)",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

ax.set_ylabel("")

# Format the x-axis as currency.
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.0f}"))

# Format tick labels.
ax.tick_params(
    axis="x",
    labelsize=11
)

# Improve grid styling.
ax.grid(
    axis="x",
    linestyle="--",
    linewidth=0.8,
    alpha=0.35
)

ax.grid(
    axis="y",
    visible=False
)

# Remove unnecessary spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

# Optimize layout.
fig.tight_layout()

# Display the visualization.
plt.show()

# %%
# Configure visualization theme.
sns.set_theme(
    style="whitegrid",
    context="notebook",
    font_scale=1.05
)

# Calculate the mean total compensation.
mean_compensation = df["total_compensation"].mean()

# Create figure and axes.
fig, ax = plt.subplots(figsize=(15, 3.8), dpi=150)

# Plot total compensation distribution.
sns.boxplot(
    data=df,
    x="total_compensation",
    width=0.45,
    color="#55A868",
    linewidth=1.2,
    flierprops={
        "marker": "o",
        "markersize": 4,
        "markerfacecolor": "#D62728",
        "markeredgecolor": "white",
        "alpha": 0.65
    },
    ax=ax
)

# Add a reference line for the mean.
ax.axvline(
    mean_compensation,
    color="#2CA02C",
    linestyle="--",
    linewidth=2
)

# Configure the chart title and axis labels.
ax.set_title(
    "Total Compensation Distribution and Outlier Detection",
    fontsize=18,
    fontweight="bold",
    pad=20
)

ax.set_xlabel(
    "Total Compensation (USD)",
    fontsize=13,
    fontweight="bold",
    labelpad=12
)

ax.set_ylabel("")

# Format the x-axis as currency.
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.0f}"))

# Format tick labels.
ax.tick_params(
    axis="x",
    labelsize=11
)

# Improve grid styling.
ax.grid(
    axis="x",
    linestyle="--",
    linewidth=0.8,
    alpha=0.35
)

ax.grid(
    axis="y",
    visible=False
)

# Remove unnecessary spines.
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.spines["left"].set_visible(False)

# Optimize layout.
fig.tight_layout()

# Display the visualization.
plt.show()

# %%
# Chart 7

sal_by_experience = (
    df.groupby("experience_level")["salary_usd"]
    .mean()
    .round(2)
)

fig, ax = plt.subplots(figsize=(15,6))

sns.barplot(
    data=sal_by_experience.reset_index(),
    x="salary_usd",
    y="experience_level",
    color="green",
    ax=ax
)

ax.set_title(
    "Average Salary Distribution based on Experience Level",
    fontsize=18,
    fontweight="bold",
    fontfamily="Cambria",
    pad=20
)

ax.set_xlabel(
    "Salary (USD)",
    fontsize=18,
    fontweight="bold",
    fontfamily="Cambria",
    labelpad=20
)

ax.set_ylabel(
    "Experience Level",
    fontsize=18,
    fontweight="bold",
    fontfamily="Cambria",
    labelpad=20
)

ax.tick_params(
    axis="both",
    labelsize=13,
    pad=18
)
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.02f}"))

sns.despine()

plt.plot()
fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "05_salary_by_experience_level.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %%
# Chart 7

sal_by_experience_years = (
    df.groupby("experience_years")["salary_usd"]
    .mean()
    .round(2)
)

fig, ax = plt.subplots(figsize=(17,6))

sns.lineplot(
    data=sal_by_experience_years.reset_index(),
    x="salary_usd",
    y="experience_years",
    color="green",
    marker="o",
    ax=ax
)

ax.set_title(
    "Average Salary Distribution based on Experience Years",
    fontsize=18,
    fontweight="bold",
    fontfamily="Cambria",
    pad=20
)

ax.set_xlabel(
    "Salary (USD)",
    fontsize=14,
    fontweight="bold",
    fontfamily="Cambria",
    labelpad=20
)

ax.set_ylabel(
    "Experience Years",
    fontsize=18,
    fontweight="bold",
    fontfamily="Cambria",
    labelpad=20
)

ax.tick_params(
    axis="y",
    labelsize=13,
    pad=18
)
ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.02f}"))

sns.despine()

fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "06_salary_by_experience_years.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %%
# Chart 9: Top 10 Countries by Average Salary

top_10_countries = (
    df.groupby("country")["salary_usd"]
    .mean()
    .round(2)
    .sort_values(ascending=False)
    .head(10)
)

fig, ax = plt.subplots(figsize=(17,6))

sns.lineplot(
    data=top_10_countries.reset_index(),
    x="salary_usd",
    y="country",
    color="steelblue",
    marker="o",
    ax=ax
)

ax.set_title(
    "Top 10 Highest Paying Countries",
    fontsize=18,
    fontweight="bold",
    fontfamily="Cambria",
    pad=20
)

ax.set_xlabel(
    "Salary (USD)",
    fontsize=14,
    labelpad=12
)

ax.set_ylabel(
    "Country",
    fontsize=18,
    fontweight="bold",
    fontfamily="Cambria",
    labelpad=20
)

ax.tick_params(
    axis="y",
    labelsize=13,
    pad=18
)

ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.02f}"))

sns.despine()

fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "07_top_10_countries_average_salary.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %%
# Chart 9: Top 10 AI Specializations by Average Salary

top_10_job_role = (
    df.groupby("job_role")["salary_usd"]
    .mean()
    .round(2)
    .sort_values(ascending=False)
    .head(10)
)

fig, ax = plt.subplots(figsize=(16,6))

sns.lineplot(
    data=top_10_job_role.reset_index(),
    y="job_role",
    x="salary_usd",
    color="steelblue",
    marker="o",
    ax=ax
)

ax.set_title(
    "Top 10 Highest paying AI Specializations by Average Salaries",
    fontsize=18,
    fontweight="bold",
    fontfamily="Cambria",
    pad=20
)

ax.set_xlabel(
    "Salary (USD)",
    fontsize=14,
    labelpad=12
)

ax.set_ylabel(
    "Job Role",
    fontsize=13,
    fontweight="bold",
    fontfamily="Cambria",
)

ax.xaxis.set_major_formatter(StrMethodFormatter("${x:,.02f}"))

sns.despine()

fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "08_salary_by_ai_specialization.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %%
# Chart 11: Average Salary by Industry

salary_by_industry = (
    df.groupby("industry")["salary_usd"]
    .mean()
    .sort_values(ascending=False)
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.lineplot(
    data=salary_by_industry.reset_index(),
    x="salary_usd",
    y="industry",
    marker="o",
    color="green",
    ax=ax
)

ax.set_title(
    "Average Salary by Industry",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Average Salary (USD)", fontsize=12)
ax.set_ylabel("Industry", fontsize=12)

sns.despine()

plt.tight_layout()
plt.show()

# %%
# Chart 12: Average Salary by Education Level

salary_by_education = (
    df.groupby("education_required")["salary_usd"]
    .mean()
    .sort_values(ascending=False)
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.lineplot(
    data=salary_by_education.reset_index(),
    x="education_required",
    y="salary_usd",
    marker="o",
    ax=ax
)

ax.set_title(
    "Average Salary by Education Level",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Education Required", fontsize=12)
ax.set_ylabel("Average Salary (USD)", fontsize=12)

# plt.xticks(rotation=20)

plt.tight_layout()
plt.show()

# %%
# Chart 13: Average Salary by AI Specialization

salary_by_specialization = (
    df.groupby("ai_specialization")["salary_usd"]
    .mean()
    .sort_values(ascending=False)
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=salary_by_specialization.reset_index(),
    x="salary_usd",
    y="ai_specialization",
    ax=ax
)

ax.set_title(
    "Average Salary by AI Specialization",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Average Salary (USD)", fontsize=12)
ax.set_ylabel("AI Specialization", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Level 3: Compensation Intelligence
#
# Objective: Visualize how salary, bonus, and total compensation compare across the AI workforce.
#
# Total Charts: 4

# %% [markdown]
# ### Chart 14: Average Bonus by Experience Level

# %%
# Chart 14: Average Bonus by Experience Level

bonus_by_experience = (
    df.groupby("experience_level")["bonus_usd"]
    .mean()
    # .reindex(experience_order)
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    data=bonus_by_experience.reset_index(),
    x="experience_level",
    y="bonus_usd",
    ax=ax
)

ax.set_title(
    "Average Bonus by Experience Level",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Average Bonus (USD)", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 15: Average Total Compensation by Experience Level

# %%
# Chart 15: Average Total Compensation by Experience Level

compensation_by_experience = (
    df.groupby("experience_level")["total_compensation"]
    .mean()
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    data=compensation_by_experience.reset_index(),
    x="experience_level",
    y="total_compensation",
    ax=ax
)

ax.set_title(
    "Average Total Compensation by Experience Level",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Average Total Compensation (USD)", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 16: Top 10 Job Roles by Average Bonus

# %%
# Chart 16: Top 10 Job Roles by Average Bonus

top_bonus_roles = (
    df.groupby("job_role")["bonus_usd"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=top_bonus_roles.reset_index(),
    x="bonus_usd",
    y="job_role",
    ax=ax
)

ax.set_title(
    "Top 10 Job Roles by Average Bonus",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Average Bonus (USD)", fontsize=12)
ax.set_ylabel("Job Role", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 17: Salary vs Bonus Relationship

# %%
# Chart 17: Salary vs Bonus Relationship

fig, ax = plt.subplots(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="salary_usd",
    y="bonus_usd",
    alpha=0.6,
    ax=ax
)

ax.set_title(
    "Relationship Between Salary and Bonus",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Salary (USD)", fontsize=12)
ax.set_ylabel("Bonus (USD)", fontsize=12)

fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "09_salary_vs_bonus_relationship.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %% [markdown]
# ### Chart 18: Experience Level Distribution of Top 10% Earners

# %%
# Chart 18: Experience Level Distribution of Top 10% Earners

top_10_salary = np.percentile(
    df["salary_usd"],
    90
)

elite_earners = (
    df[df["salary_usd"] >= top_10_salary]
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.countplot(
    data=elite_earners,
    x="experience_level",
    # order=experience_order,
    ax=ax
)

ax.set_title(
    "Experience Level Distribution Among Top 10% Earners",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Number of Job Records", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 19: Top 10 Countries Among Elite Earners

# %%
# Chart 19: Top 10 Countries Among Elite Earners

elite_countries = (
    elite_earners["country"]
    .value_counts()
    .head(10)
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=elite_countries.reset_index(),
    x="count",
    y="country",
    ax=ax
)

ax.set_title(
    "Top 10 Countries Among Elite Earners",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Number of Job Records", fontsize=12)
ax.set_ylabel("Country", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 20: Top 10 Job Roles Among Elite Earners

# %%
# Chart 20: Top 10 Job Roles Among Elite Earners

elite_roles = (
    elite_earners["job_role"]
    .value_counts()
    .head(10)
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=elite_roles.reset_index(),
    x="count",
    y="job_role",
    ax=ax
)

ax.set_title(
    "Top 10 Job Roles Among Elite Earners",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Number of Job Records", fontsize=12)
ax.set_ylabel("Job Role", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 21: Top AI Specializations Among Elite Earners

# %%
# Chart 21: Top AI Specializations Among Elite Earners

elite_specializations = (
    elite_earners["ai_specialization"]
    .value_counts()
    .head(10)
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=elite_specializations.reset_index(),
    x="count",
    y="ai_specialization",
    ax=ax
)

ax.set_title(
    "Top AI Specializations Among Elite Earners",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Number of Job Records", fontsize=12)
ax.set_ylabel("AI Specialization", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Level 5: Career Journey Analytics
#
# Objective: Visualize how salary and compensation evolve throughout an AI professional's career.
#
# This section should tell a career story, not just compare categories.
#
# Total Charts: 4

# %% [markdown]
# ### Chart 22: Average Salary Across Experience Levels

# %%
# Chart 22: Average Salary Across Experience Levels

salary_journey = (
    df.groupby("experience_level")["salary_usd"]
    .mean()
    # .reindex(experience_order)
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.lineplot(
    data=salary_journey.reset_index(),
    x="experience_level",
    y="salary_usd",
    marker="o",
    linewidth=3,
    markersize=8,
    ax=ax
)

ax.set_title(
    "Career Salary Journey Across Experience Levels",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Average Salary (USD)", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 23: Average Bonus Across Experience Levels

# %%
# Chart 23: Average Bonus Across Experience Levels

bonus_journey = (
    df.groupby("experience_level")["bonus_usd"]
    .mean()
    # .reindex(experience_order)
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.lineplot(
    data=bonus_journey.reset_index(),
    x="experience_level",
    y="bonus_usd",
    marker="o",
    linewidth=3,
    markersize=8,
    ax=ax
)

ax.set_title(
    "Career Bonus Journey Across Experience Levels",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Average Bonus (USD)", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 24: Average Total Compensation Across Experience Levels

# %%
# Chart 24: Average Total Compensation Across Experience Levels

compensation_journey = (
    df.groupby("experience_level")["total_compensation"]
    .mean()
    # .reindex(experience_order)
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.lineplot(
    data=compensation_journey.reset_index(),
    x="experience_level",
    y="total_compensation",
    marker="o",
    linewidth=3,
    markersize=8,
    ax=ax
)

ax.set_title(
    "Career Total Compensation Journey",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Average Total Compensation (USD)", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 25: Salary Growth by Experience Years

# %%
# Chart 25: Salary Growth by Experience Years

salary_by_years = (
    df.groupby("experience_years")["salary_usd"]
    .mean()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.lineplot(
    data=salary_by_years.reset_index(),
    x="experience_years",
    y="salary_usd",
    marker="o",
    linewidth=2.5,
    ax=ax
)

ax.set_title(
    "Average Salary Growth by Experience Years",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience (Years)", fontsize=12)
ax.set_ylabel("Average Salary (USD)", fontsize=12)

fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "10_salary_growth_by_experience_years.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %% [markdown]
# ### Level 6: Multi-Factor Visual Analytics
#
# Objective:
# Visualize how two business dimensions together influence salary. Heatmaps are ideal because they reveal patterns that are difficult to spot in tables.
#
# Total Charts: 5

# %% [markdown]
# ### Chart 26: Average Salary by Country and Experience Level

# %%
# Chart 26: Average Salary by Country and Experience Level

salary_country_experience = (
    pd.pivot_table(
        df,
        values="salary_usd",
        index="country",
        columns="experience_level",
        aggfunc="mean"
    )
)

fig, ax = plt.subplots(figsize=(14, 8))

sns.heatmap(
    salary_country_experience,
    annot=True,
    fmt=".0f",
    cmap="YlGnBu",
    linewidths=0.5,
    ax=ax
)

ax.set_title(
    "Average Salary by Country and Experience Level",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Country", fontsize=12)

fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "11_salary_country_experience_heatmap.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %% [markdown]
# ### Chart 27: Average Salary by Industry and Experience Level

# %%
# Chart 27: Average Salary by Industry and Experience Level

salary_industry_experience = (
    pd.pivot_table(
        df,
        values="salary_usd",
        index="industry",
        columns="experience_level",
        aggfunc="mean"
    )
)

fig, ax = plt.subplots(figsize=(14, 8))

sns.heatmap(
    salary_industry_experience,
    annot=True,
    fmt=".0f",
    cmap="YlOrRd",
    linewidths=0.5,
    ax=ax
)

ax.set_title(
    "Average Salary by Industry and Experience Level",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Industry", fontsize=12)

fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "12_salary_industry_experience_heatmap.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %% [markdown]
# ### Chart 28: Average Salary by AI Specialization and Experience Level

# %%
# Chart 28: Average Salary by AI Specialization and Experience Level

salary_specialization_experience = (
    pd.pivot_table(
        df,
        values="salary_usd",
        index="ai_specialization",
        columns="experience_level",
        aggfunc="mean"
    )
)

fig, ax = plt.subplots(figsize=(14, 8))

sns.heatmap(
    salary_specialization_experience,
    annot=True,
    fmt=".0f",
    cmap="PuBuGn",
    linewidths=0.5,
    ax=ax
)

ax.set_title(
    "Average Salary by AI Specialization and Experience Level",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("AI Specialization", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 29: Average Salary by Education and Experience Level

# %%
# Chart 29: Average Salary by Education and Experience Level

salary_education_experience = (
    pd.pivot_table(
        df,
        values="salary_usd",
        index="education_required",
        columns="experience_level",
        aggfunc="mean"
    )
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.heatmap(
    salary_education_experience,
    annot=True,
    fmt=".0f",
    cmap="BuPu",
    linewidths=0.5,
    ax=ax
)

ax.set_title(
    "Average Salary by Education and Experience Level",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Education Required", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 30: Average Salary by Job Role and Experience Level

# %%
# Chart 30: Average Salary by Job Role and Experience Level

salary_role_experience = (
    pd.pivot_table(
        df,
        values="salary_usd",
        index="job_role",
        columns="experience_level",
        aggfunc="mean"
    )
)

fig, ax = plt.subplots(figsize=(16, 10))

sns.heatmap(
    salary_role_experience,
    annot=True,
    fmt=".0f",
    cmap="YlGn",
    linewidths=0.5,
    ax=ax
)

ax.set_title(
    "Average Salary by Job Role and Experience Level",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Experience Level", fontsize=12)
ax.set_ylabel("Job Role", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Level 7: Workforce Metrics Visual Analytics
#
# These charts visualize the engineered features you created in Level 8 of Workforce Analytics.
#
# Total Charts: 4

# %% [markdown]
# ### Chart 31: Bonus Percentage Distribution

# %%
# Chart 31: Bonus Percentage Distribution

df["bonus_percentage"] = (
    (df["bonus_usd"] / df["salary_usd"]) * 100
).round(2)

df["bonus_percentage"].describe().round(2)

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="bonus_percentage",
    bins=30,
    kde=True,
    ax=ax
)

ax.set_title(
    "Distribution of Bonus Percentage",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Bonus Percentage (%)", fontsize=12)
ax.set_ylabel("Number of Job Records", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 32: Career Value Index Distribution

# %%
# Chart 32: Career Value Index Distribution

df["career_value_index"] = (
    (
        df["salary_usd"]
        * df["career_growth_score"]
        * df["job_security_score"]
    )
    / 10000
).round(2)

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="career_value_index",
    bins=30,
    kde=True,
    ax=ax
)

ax.set_title(
    "Distribution of Career Value Index",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Career Value Index", fontsize=12)
ax.set_ylabel("Number of Job Records", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 33: Reward-Risk Ratio Distribution

# %%
# Chart 33: Reward-Risk Ratio Distribution

df["reward_risk_ratio"] = (
    df["salary_usd"]
    / (df["layoff_risk"] + 1)
).round(2)

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="reward_risk_ratio",
    bins=30,
    kde=True,
    ax=ax
)

ax.set_title(
    "Distribution of Reward-Risk Ratio",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Reward-Risk Ratio", fontsize=12)
ax.set_ylabel("Number of Job Records", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Chart 34: Salary Efficiency Index Distribution

# %%
# Chart 34: Salary Efficiency Index Distribution

df["salary_efficiency_index"] = (
    df["salary_usd"]
    / df["skill_demand_score"]
).round(2)

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="salary_efficiency_index",
    bins=30,
    kde=True,
    ax=ax
)

ax.set_title(
    "Distribution of Salary Efficiency Index",
    fontsize=16,
    fontweight="bold"
)

ax.set_xlabel("Salary Efficiency Index", fontsize=12)
ax.set_ylabel("Number of Job Records", fontsize=12)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Level 8: Correlation Analytics
#
# This should contain only 2 charts.
#
# These are the last charts for Module 1.

# %% [markdown]
# ### Chart 35: Correlation Matrix of Numerical Features

# %%
# Chart 35: Correlation Matrix of Numerical Features

correlation_matrix = df.corr(numeric_only=True)

fig, ax = plt.subplots(figsize=(18, 12))

sns.heatmap(
    correlation_matrix,
    cmap="coolwarm",
    center=0,
    linewidths=0.5,
    ax=ax
)

ax.set_title(
    "Correlation Matrix of Numerical Features",
    fontsize=18,
    fontweight="bold"
)

fig.tight_layout()

fig.savefig(
    VISUALIZATION_DIR / "01_salary_intelligence" / "13_correlation_matrix.png",
    dpi=300,
    bbox_inches="tight",
    facecolor="white"
)

plt.show()
plt.close(fig)

# %% [markdown]
# ### Chart 36: Salary Intelligence Correlation Matrix
#
# This chart focuses only on variables that influence salary.

# %%
# Chart 36: Salary Intelligence Correlation Matrix

salary_columns = [
    "salary_usd",
    "bonus_usd",
    "total_compensation",
    "experience_years",
    "company_rating",
    "career_growth_score",
    "job_security_score",
    "skill_demand_score",
    "promotion_speed",
    "offer_acceptance_rate",
    "bonus_percentage",
    "salary_efficiency_index",
    "career_value_index",
    "reward_risk_ratio"
]

salary_correlation = (
    df[salary_columns]
    .corr()
)

fig, ax = plt.subplots(figsize=(12, 10))

sns.heatmap(
    salary_correlation,
    annot=True,
    fmt=".2f",
    cmap="RdBu_r",
    center=0,
    linewidths=0.5,
    ax=ax
)

ax.set_title(
    "Salary Intelligence Correlation Matrix",
    fontsize=18,
    fontweight="bold"
)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 02 Career Growth Visuals

# %% [markdown]
# # Career Growth Intelligence - Visual Analytics
#
# This notebook contains production-ready visualizations for the Career Growth Intelligence module. Each chart is presented with a short business objective followed by the corresponding visualization code.

# %% [markdown]
# ## Chart 1: Career Growth Score Distribution
#
# **Business Objective:** Visualize **career growth score distribution** to support career growth analysis and decision-making.

# %%
# Chart 1: Career Growth Score Distribution

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="career_growth_score",
    bins=30,
    kde=True,
    color="royalblue",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title(
    "Distribution of Career Growth Scores",
    fontsize=16,
    fontweight="bold",
    pad=15
)

ax.set_xlabel("Career Growth Score", fontsize=12)
ax.set_ylabel("Number of Professionals", fontsize=12)
ax.grid(axis="y", linestyle="--", alpha=0.3)

sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "02_career_growth" / "01_career_growth_score_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 2: Promotion Speed Distribution
#
# **Business Objective:** Visualize **promotion speed distribution** to support career growth analysis and decision-making.

# %%
# Chart 2: Promotion Speed Distribution

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="promotion_speed",
    bins=30,
    kde=True,
    color="seagreen",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Promotion Speed", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Promotion Speed", fontsize=12)
ax.set_ylabel("Number of Professionals", fontsize=12)
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart 3: Career Growth by Experience Level
#
# **Business Objective:** Visualize **career growth by experience level** to support career growth analysis and decision-making.

# %%
# Chart 3: Career Growth by Experience Level

career_growth_exp = (
    df.groupby("experience_level", observed=False)["career_growth_score"]
    .mean()
    .reset_index()
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    data=career_growth_exp,
    x="experience_level",
    y="career_growth_score",
    color="steelblue",
    ax=ax
)

ax.set_title(
    "Average Career Growth by Experience Level",
    fontsize=16,
    fontweight="bold",
    pad=15
)

ax.set_xlabel("Experience Level")
ax.set_ylabel("Career Growth Score")

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "02_career_growth" / "02_career_growth_by_experience_level.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 4: Top 10 Countries by Career Growth
#
# **Business Objective:** Visualize **top 10 countries by career growth** to support career growth analysis and decision-making.

# %%
# Chart 4: Top 10 Countries by Career Growth

career_country = (
    df.groupby("country")["career_growth_score"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=career_country,
    x="career_growth_score",
    y="country",
    color="darkorange",
    ax=ax
)

ax.set_title(
    "Top 10 Countries by Career Growth Score",
    fontsize=16,
    fontweight="bold",
    pad=15
)

ax.set_xlabel("Career Growth Score")
ax.set_ylabel("Country")

ax.grid(
    axis="x",
    linestyle="--",
    alpha=0.3
)

sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "02_career_growth" / "03_top_10_countries_by_career_growth.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 5: Top 10 Job Roles by Career Growth
#
# **Business Objective:** Visualize **top 10 job roles by career growth** to support career growth analysis and decision-making.

# %%
# Chart 5: Top 10 Job Roles by Career Growth

career_role = (
    df.groupby("job_role")["career_growth_score"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=career_role,
    x="career_growth_score",
    y="job_role",
    color="mediumpurple",
    ax=ax
)

ax.set_title(
    "Top 10 Job Roles by Career Growth Score",
    fontsize=16,
    fontweight="bold",
    pad=15
)

ax.set_xlabel("Career Growth Score")
ax.set_ylabel("Job Role")

ax.grid(
    axis="x",
    linestyle="--",
    alpha=0.3
)

sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "02_career_growth" / "04_top_10_job_roles_by_career_growth.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 6: Career Growth by AI Specialization
#
# **Business Objective:** Visualize **career growth by ai specialization** to support career growth analysis and decision-making.

# %%
# Chart 6: Career Growth by AI Specialization

career_specialization = (
    df.groupby("ai_specialization")["career_growth_score"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 7))

sns.barplot(
    data=career_specialization,
    x="career_growth_score",
    y="ai_specialization",
    color="teal",
    ax=ax
)

ax.set_title(
    "Average Career Growth by AI Specialization",
    fontsize=16,
    fontweight="bold",
    pad=15
)

ax.set_xlabel("Career Growth Score")
ax.set_ylabel("AI Specialization")

ax.grid(
    axis="x",
    linestyle="--",
    alpha=0.3
)

sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "02_career_growth" / "05_career_growth_by_ai_specialization.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 7: Promotion Speed by Experience Level
#
# **Business Objective:** Visualize **promotion speed by experience level** to support career growth analysis and decision-making.

# %%
# Chart 7: Promotion Speed by Experience Level

promotion_exp = (
    df.groupby("experience_level", observed=False)["promotion_speed"]
    .mean()
    .reset_index()
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    data=promotion_exp,
    x="experience_level",
    y="promotion_speed",
    color="indianred",
    ax=ax
)

ax.set_title(
    "Average Promotion Speed by Experience Level",
    fontsize=16,
    fontweight="bold",
    pad=15
)

ax.set_xlabel("Experience Level")
ax.set_ylabel("Promotion Speed")

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "02_career_growth" / "06_promotion_speed_by_experience_level.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 8: Salary vs Career Growth
#
# **Business Objective:** Visualize **salary vs career growth** to support career growth analysis and decision-making.

# %%
# Chart 8: Salary vs Career Growth

fig, ax = plt.subplots(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="salary_usd",
    y="career_growth_score",
    alpha=0.35,
    s=35,
    ax=ax
)

ax.set_title("Salary vs Career Growth Score", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Salary (USD)")
ax.set_ylabel("Career Growth Score")
ax.grid(True, linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart 9: Career Growth by Experience Years
#
# **Business Objective:** Visualize **career growth by experience years** to support career growth analysis and decision-making.

# %%
# Chart 9: Career Growth by Experience Years

career_years = (
    df.groupby("experience_years")["career_growth_score"]
    .mean()
)

fig, ax = plt.subplots(figsize=(12,6))

sns.lineplot(
    data=career_years.reset_index(),
    x="experience_years",
    y="career_growth_score",
    marker="o",
    linewidth=2.5,
    ax=ax
)

ax.set_title("Career Growth Across Experience Years", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Experience Years")
ax.set_ylabel("Career Growth Score")
ax.grid(True, linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart 10: Correlation Heatmap
#
# **Business Objective:** Visualize **correlation heatmap** to support career growth analysis and decision-making.

# %%
# Chart 10: Career Growth Correlation Heatmap

career_corr = (
    df[[
        "career_growth_score",
        "promotion_speed",
        "salary_percentile",
        "experience_years",
        "salary_usd",
        "bonus_usd",
        "skill_demand_score",
        "job_security_score",
        "employee_satisfaction",
        "work_life_balance_score"
    ]]
    .corr()
)

fig, ax = plt.subplots(figsize=(10, 8))

sns.heatmap(
    career_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.8},
    ax=ax
)

ax.set_title(
    "Career Growth Correlation Matrix",
    fontsize=16,
    fontweight="bold",
    pad=15
)

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "02_career_growth" / "07_career_growth_correlation_heatmap.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # 03 Workforce Risk Visuals

# %% [markdown]
# # Workforce Risk Intelligence - Visual Analytics
#
# This notebook contains production-ready visualizations for the Workforce Risk Intelligence module. Each chart includes a brief business objective followed by the visualization code.

# %% [markdown]
# ## Chart 1: Job Security Score Distribution
#
# **Business Objective:** Visualize job security score distribution to understand workforce risk patterns and support business decision-making.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="job_security_score",
    bins=30,
    kde=True,
    color="forestgreen",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Job Security Scores", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Job Security Score", fontsize=12)
ax.set_ylabel("Number of Professionals", fontsize=12)
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "03_workforce_risk" / "01_job_security_score_distribution.png",
    dpi=300,
    bbox_inches="tight"
)
plt.show()

# %% [markdown]
# ## Chart 2: Layoff Risk Distribution
#
# **Business Objective:** Visualize layoff risk distribution to understand workforce risk patterns and support business decision-making.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="layoff_risk",
    bins=30,
    kde=True,
    color="firebrick",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Layoff Risk", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Layoff Risk")
ax.set_ylabel("Number of Professionals")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "03_workforce_risk" / "02_layoff_risk_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 3: Automation Risk Distribution
#
# **Business Objective:** Visualize automation risk distribution to understand workforce risk patterns and support business decision-making.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="automation_risk",
    bins=30,
    kde=True,
    color="darkorange",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Automation Risk", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Automation Risk")
ax.set_ylabel("Number of Professionals")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart 4: Job Security by Experience Level
#
# **Business Objective:** Visualize job security by experience level to understand workforce risk patterns and support business decision-making.

# %%
# Experience Level Order

experience_order = [
    "Entry",
    "Mid",
    "Senior",
    "Lead"
]

job_security_exp = (
    df.groupby("experience_level", observed=False)["job_security_score"]
    .mean()
    .reindex(experience_order)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(10, 6))

sns.barplot(
    data=job_security_exp,
    x="experience_level",
    y="job_security_score",
    color="seagreen",
    ax=ax
)

ax.set_title("Average Job Security by Experience Level", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Experience Level")
ax.set_ylabel("Job Security Score")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "03_workforce_risk" / "03_job_security_by_experience_level.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 5: Top 10 Countries by Job Security
#
# **Business Objective:** Visualize top 10 countries by job security to understand workforce risk patterns and support business decision-making.

# %%
job_security_country = (
    df.groupby("country")["job_security_score"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=job_security_country,
    x="job_security_score",
    y="country",
    color="mediumseagreen",
    ax=ax
)

ax.set_title("Top 10 Countries by Job Security", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Job Security Score")
ax.set_ylabel("Country")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "03_workforce_risk" / "04_top_10_countries_by_job_security.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 6: Top 10 Job Roles by Automation Risk
#
# **Business Objective:** Visualize top 10 job roles by automation risk to understand workforce risk patterns and support business decision-making.

# %%
automation_role = (
    df.groupby("job_role")["automation_risk"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=automation_role,
    x="automation_risk",
    y="job_role",
    color="tomato",
    ax=ax
)

ax.set_title("Top 10 Job Roles by Automation Risk", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Automation Risk")
ax.set_ylabel("Job Role")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "03_workforce_risk" / "05_top_10_job_roles_by_automation_risk.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 7: AI Adoption by Industry
#
# **Business Objective:** Visualize ai adoption by industry to understand workforce risk patterns and support business decision-making.

# %%
ai_adoption = (
    df.groupby("industry")["ai_adoption_score"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=ai_adoption,
    x="ai_adoption_score",
    y="industry",
    color="royalblue",
    ax=ax
)

ax.set_title("Average AI Adoption Score by Industry", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("AI Adoption Score")
ax.set_ylabel("Industry")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "03_workforce_risk" / "06_ai_adoption_score_by_industry.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 8: Layoff Risk vs Job Security
#
# **Business Objective:** Visualize layoff risk vs job security to understand workforce risk patterns and support business decision-making.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="layoff_risk",
    y="job_security_score",
    alpha=0.35,
    s=35,
    ax=ax
)

ax.set_title("Layoff Risk vs Job Security", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Layoff Risk")
ax.set_ylabel("Job Security Score")
ax.grid(True, linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %%
# Create Engineered Workforce Risk Features

df["workforce_stability_index"] = (
    (
        df["job_security_score"] +
        df["ai_adoption_score"] +
        (100 - df["layoff_risk"] * 100)
    ) / 3
).round(2)

df["automation_resilience_score"] = (
    (
        df["job_security_score"] +
        (100 - df["automation_risk"])
    ) / 2
).round(2)

df["risk_exposure_index"] = (
    (
        (df["layoff_risk"] * 100) +
        df["automation_risk"]
    ) / 2
).round(2)

df["ai_workforce_readiness_score"] = (
    (
        df["job_security_score"] +
        df["ai_adoption_score"] +
        df["skill_demand_score"]
    ) / 3
).round(2)

df["stability_risk_ratio"] = (
    df["job_security_score"] /
    (df["layoff_risk"] * 100 + 1)
).round(2)

# %% [markdown]
# ## Chart 9: Workforce Stability Index Distribution
#
# **Business Objective:** Visualize workforce stability index distribution to understand workforce risk patterns and support business decision-making.

# %%
# Chart 9: Workforce Stability Index Distribution

fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="workforce_stability_index",
    bins=30,
    kde=True,
    color="purple",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title(
    "Distribution of Workforce Stability Index",
    fontsize=16,
    fontweight="bold",
    pad=15
)

ax.set_xlabel("Workforce Stability Index")
ax.set_ylabel("Number of Professionals")

ax.grid(
    axis="y",
    linestyle="--",
    alpha=0.3
)

sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "03_workforce_risk" / "07_workforce_stability_index_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 10: Workforce Risk Correlation Matrix
#
# **Business Objective:** Visualize workforce risk correlation matrix to understand workforce risk patterns and support business decision-making.

# %%
# Chart 10: Workforce Risk Correlation Matrix

risk_corr = (
    df[
        [
            "job_security_score",
            "layoff_risk",
            "automation_risk",
            "ai_adoption_score",
            "workforce_stability_index",
            "automation_resilience_score",
            "risk_exposure_index",
            "ai_workforce_readiness_score",
            "stability_risk_ratio"
        ]
    ]
    .corr()
)

fig, ax = plt.subplots(figsize=(10, 8))

sns.heatmap(
    risk_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.8},
    ax=ax
)

ax.set_title(
    "Workforce Risk Correlation Matrix",
    fontsize=16,
    fontweight="bold",
    pad=15
)

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "03_workforce_risk" / "08_workforce_risk_correlation_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # 04 Talent Market Visuals

# %% [markdown]
# # Talent Market Intelligence - Visual Analytics
#
# This notebook contains production-ready visualizations for the Talent Market Intelligence module. Each chart includes a brief business objective followed by the visualization code.

# %% [markdown]
# ## Chart 1: Job Openings Distribution
#
# **Business Objective:** Visualize job openings distribution to understand talent demand and recruitment trends.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="job_openings",
    bins=30,
    kde=True,
    color="royalblue",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Job Openings", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Job Openings")
ax.set_ylabel("Number of Records")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "04_talent_market" / "01_job_openings_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 2: Skill Demand Score Distribution
#
# **Business Objective:** Visualize skill demand score distribution to understand talent demand and recruitment trends.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="skill_demand_score",
    bins=30,
    kde=True,
    color="seagreen",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Skill Demand Score", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Skill Demand Score")
ax.set_ylabel("Number of Records")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Chart 3: Hiring Difficulty Distribution
#
# **Business Objective:** Visualize hiring difficulty distribution to understand talent demand and recruitment trends.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="hiring_difficulty_score",
    bins=30,
    kde=True,
    color="darkorange",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Hiring Difficulty Score", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Hiring Difficulty Score")
ax.set_ylabel("Number of Records")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "04_talent_market" / "03_hiring_difficulty_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 4: Top 10 Countries by Job Openings
#
# **Business Objective:** Visualize top 10 countries by job openings to understand talent demand and recruitment trends.

# %%
country_openings = (
    df.groupby("country")["job_openings"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=country_openings,
    x="job_openings",
    y="country",
    color="cornflowerblue",
    ax=ax
)

ax.set_title("Top 10 Countries by Average Job Openings", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Average Job Openings")
ax.set_ylabel("Country")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "04_talent_market" / "04_top_10_countries_by_job_openings.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 5: Top 10 Job Roles by Job Openings
#
# **Business Objective:** Visualize top 10 job roles by job openings to understand talent demand and recruitment trends.

# %%
role_openings = (
    df.groupby("job_role")["job_openings"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=role_openings,
    x="job_openings",
    y="job_role",
    color="mediumpurple",
    ax=ax
)

ax.set_title("Top 10 Job Roles by Average Job Openings", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Average Job Openings")
ax.set_ylabel("Job Role")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "04_talent_market" / "05_top_10_job_roles_by_job_openings.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 6: Skill Demand by AI Specialization
#
# **Business Objective:** Visualize skill demand by ai specialization to understand talent demand and recruitment trends.

# %%
specialization_demand = (
    df.groupby("ai_specialization")["skill_demand_score"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=specialization_demand,
    x="skill_demand_score",
    y="ai_specialization",
    color="teal",
    ax=ax
)

ax.set_title("Average Skill Demand by AI Specialization", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Skill Demand Score")
ax.set_ylabel("AI Specialization")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "04_talent_market" / "06_skill_demand_by_ai_specialization.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 7: Hiring Difficulty by Job Role
#
# **Business Objective:** Visualize hiring difficulty by job role to understand talent demand and recruitment trends.

# %%
hiring_role = (
    df.groupby("job_role")["hiring_difficulty_score"]
    .mean()
    .sort_values(ascending=False)
    .reset_index()
)

fig, ax = plt.subplots(figsize=(12, 6))

sns.barplot(
    data=hiring_role,
    x="hiring_difficulty_score",
    y="job_role",
    color="indianred",
    ax=ax
)

ax.set_title("Average Hiring Difficulty by Job Role", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Hiring Difficulty Score")
ax.set_ylabel("Job Role")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "04_talent_market" / "07_hiring_difficulty_by_job_role.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 8: Job Openings vs Skill Demand
#
# **Business Objective:** Visualize job openings vs skill demand to understand talent demand and recruitment trends.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.scatterplot(
    data=df,
    x="skill_demand_score",
    y="job_openings",
    alpha=0.35,
    s=35,
    ax=ax
)

ax.set_title("Job Openings vs Skill Demand", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Skill Demand Score")
ax.set_ylabel("Job Openings")
ax.grid(True, linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %%
# Create Engineered Talent Market Features

df["talent_demand_index"] = (
    (
        df["job_openings"] +
        df["skill_demand_score"] +
        df["ai_adoption_score"]
    ) / 3
).round(2)

df["hiring_efficiency_score"] = (
    df["job_openings"] /
    (df["interview_rounds"] + 1)
).round(2)

df["market_opportunity_index"] = (
    (
        df["job_openings"] +
        df["career_growth_score"] +
        df["salary_percentile"]
    ) / 3
).round(2)

df["skill_premium_index"] = (
    (
        df["skill_demand_score"] *
        df["salary_percentile"]
    ) / 100
).round(2)

df["recruitment_competitiveness_score"] = (
    (
        df["skill_demand_score"] +
        df["hiring_difficulty_score"] +
        (df["interview_rounds"] * 10)
    ) / 3
).round(2)

# %% [markdown]
# ## Chart 9: Talent Demand Index Distribution
#
# **Business Objective:** Visualize talent demand index distribution to understand talent demand and recruitment trends.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="talent_demand_index",
    bins=30,
    kde=True,
    color="purple",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Talent Demand Index", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Talent Demand Index")
ax.set_ylabel("Number of Records")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "04_talent_market" / "08_talent_demand_index_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# ## Chart 10: Talent Market Correlation Matrix
#
# **Business Objective:** Visualize talent market correlation matrix to understand talent demand and recruitment trends.

# %%
# Chart 10: Talent Market Correlation Matrix

talent_corr = (
    df[
        [
            "job_openings",
            "skill_demand_score",
            "hiring_difficulty_score",
            "interview_rounds",
            "talent_demand_index",
            "hiring_efficiency_score",
            "market_opportunity_index",
            "skill_premium_index",
            "recruitment_competitiveness_score"
        ]
    ]
    .corr()
)

fig, ax = plt.subplots(figsize=(14, 8))

sns.heatmap(
    talent_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.8},
    ax=ax
)

ax.set_title(
    "Talent Market Correlation Matrix",
    fontsize=16,
    fontweight="bold",
    pad=15
)

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "04_talent_market" / "09_talent_market_correlation_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # 05 Employee Experience Visuals

# %% [markdown]
# # Chart 1: Employee Satisfaction Distribution
#
# **Business Objective:** Visualize the distribution of employee satisfaction across the workforce.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="employee_satisfaction",
    bins=30,
    kde=True,
    color="steelblue",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Employee Satisfaction", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Employee Satisfaction")
ax.set_ylabel("Number of Employees")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "05_employee_experience" / "01_employee_satisfaction_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 2: Work-Life Balance Distribution
#
# **Business Objective:** Analyze the distribution of work-life balance scores.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="work_life_balance_score",
    bins=30,
    kde=True,
    color="seagreen",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Work-Life Balance Score", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Work-Life Balance Score")
ax.set_ylabel("Number of Employees")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "05_employee_experience" / "02_work_life_balance_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 3: Employee Satisfaction by Work Mode
#
# **Business Objective:** Compare average employee satisfaction across work modes.

# %%
employee_work_mode=(
    df.groupby("work_mode")["employee_satisfaction"]
    .mean()
)

fig, ax=plt.subplots(figsize=(10,6))

sns.barplot(
    data=employee_work_mode.reset_index(),
    x="work_mode",
    y="employee_satisfaction",
    color="steelblue",
    ax=ax
)

ax.set_title("Average Employee Satisfaction by Work Mode", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Work Mode")
ax.set_ylabel("Employee Satisfaction")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Chart 4: Work-Life Balance by Work Mode
#
# **Business Objective:** Compare work-life balance across work modes.

# %%
wlb_work_mode=(
    df.groupby("work_mode")["work_life_balance_score"]
    .mean()
)

fig, ax=plt.subplots(figsize=(10,6))

sns.barplot(
    data=wlb_work_mode.reset_index(),
    x="work_mode",
    y="work_life_balance_score",
    color="darkorange",
    ax=ax
)

ax.set_title("Average Work-Life Balance by Work Mode", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Work Mode")
ax.set_ylabel("Work-Life Balance Score")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "05_employee_experience" / "04_work_life_balance_by_work_mode.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 5: Top 10 Countries by Employee Satisfaction
#
# **Business Objective:** Identify countries with the highest employee satisfaction.

# %%
employee_country=(
    df.groupby("country")["employee_satisfaction"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

fig, ax=plt.subplots(figsize=(12,6))

sns.barplot(
    data=employee_country.reset_index(),
    x="employee_satisfaction",
    y="country",
    color="mediumpurple",
    ax=ax
)

ax.set_title("Top 10 Countries by Employee Satisfaction", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Employee Satisfaction")
ax.set_ylabel("Country")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "05_employee_experience" / "05_top_10_countries_by_employee_satisfaction.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 6: Company Rating vs Employee Satisfaction
#
# **Business Objective:** Examine the relationship between company rating and employee satisfaction.

# %%
company_rating=(
    df.groupby("company_rating")["employee_satisfaction"]
    .mean()
)

fig, ax=plt.subplots(figsize=(10,6))

sns.lineplot(
    data=company_rating.reset_index(),
    x="company_rating",
    y="employee_satisfaction",
    marker="o",
    linewidth=2.5,
    ax=ax
)

ax.set_title("Company Rating vs Employee Satisfaction", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Company Rating")
ax.set_ylabel("Employee Satisfaction")
ax.grid(linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "05_employee_experience" / "06_company_rating_vs_employee_satisfaction.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 7: Weekly Hours vs Employee Satisfaction
#
# **Business Objective:** Analyze how weekly working hours relate to employee satisfaction.

# %%
fig, ax=plt.subplots(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="weekly_hours",
    y="employee_satisfaction",
    alpha=0.45,
    s=35,
    color="crimson",
    ax=ax
)

ax.set_title("Weekly Working Hours vs Employee Satisfaction", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Weekly Working Hours")
ax.set_ylabel("Employee Satisfaction")
ax.grid(linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Chart 8: Employee Experience Correlation Matrix
#
# **Business Objective:** Understand correlations among employee experience metrics.

# %%
# Create Engineered Features if They Do Not Exist

if "employee_experience_index" not in df.columns:

    df["employee_experience_index"] = (
        (
            df["employee_satisfaction"] +
            df["work_life_balance_score"] +
            df["company_rating"] * 20
        ) / 3
    ).round(2)

if "wellbeing_score" not in df.columns:

    df["wellbeing_score"] = (
        (
            df["employee_satisfaction"] +
            df["work_life_balance_score"] +
            (100 - df["weekly_hours"])
        ) / 3
    ).round(2)


# Employee Experience Correlation Matrix

employee_corr = (
    df[
        [
            "employee_satisfaction",
            "work_life_balance_score",
            "weekly_hours",
            "vacation_days",
            "company_rating",
            "employee_experience_index",
            "wellbeing_score"
        ]
    ]
    .corr()
)

fig, ax = plt.subplots(figsize=(12, 7))

sns.heatmap(
    employee_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink": 0.8},
    ax=ax
)

ax.set_title(
    "Employee Experience Correlation Matrix",
    fontsize=16,
    fontweight="bold",
    pad=15
)

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "05_employee_experience" / "07_employee_experience_correlation_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # 06 Recruitment Visuals

# %% [markdown]
# # Chart 1: Offer Acceptance Rate Distribution
#
# **Business Objective:** Visualize the distribution of offer acceptance rates.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="offer_acceptance_rate",
    bins=30,
    kde=True,
    color="steelblue",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Offer Acceptance Rate", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Offer Acceptance Rate (%)")
ax.set_ylabel("Number of Candidates")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "06_recruitment" / "01_offer_acceptance_rate_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 2: Hiring Difficulty Score Distribution
#
# **Business Objective:** Visualize the distribution of hiring difficulty.

# %%
fig, ax = plt.subplots(figsize=(10, 6))

sns.histplot(
    data=df,
    x="hiring_difficulty_score",
    bins=30,
    kde=True,
    color="darkorange",
    edgecolor="white",
    linewidth=0.5,
    alpha=0.85,
    ax=ax
)

ax.set_title("Distribution of Hiring Difficulty Score", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Hiring Difficulty Score")
ax.set_ylabel("Number of Positions")
ax.grid(axis="y", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "06_recruitment" / "02_hiring_difficulty_score_distribution.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 3: Top 10 Countries by Offer Acceptance Rate
#
# **Business Objective:** Compare countries by average offer acceptance.

# %%
country_acceptance=(df.groupby("country")["offer_acceptance_rate"].mean().sort_values(ascending=False).head(10))

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(
    data=country_acceptance.reset_index(),
    x="offer_acceptance_rate",
    y="country",
    color="forestgreen",
    ax=ax
)

ax.set_title("Top 10 Countries by Offer Acceptance Rate", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Offer Acceptance Rate (%)")
ax.set_ylabel("Country")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "06_recruitment" / "03_top_10_countries_by_offer_acceptance_rate.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 4: Top 10 Job Roles by Offer Acceptance Rate
#
# **Business Objective:** Compare job roles by average offer acceptance.

# %%
role_acceptance=(df.groupby("job_role")["offer_acceptance_rate"].mean().sort_values(ascending=False).head(10))

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(
    data=role_acceptance.reset_index(),
    x="offer_acceptance_rate",
    y="job_role",
    color="mediumpurple",
    ax=ax
)


ax.set_title("Top 10 Job Roles by Offer Acceptance Rate", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Offer Acceptance Rate (%)")
ax.set_ylabel("Job Role")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "06_recruitment" / "04_top_10_job_roles_by_offer_acceptance_rate.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 5: Offer Acceptance Rate by Industry
#
# **Business Objective:** Compare industries by offer acceptance.

# %%
industry_acceptance=(df.groupby("industry")["offer_acceptance_rate"].mean().sort_values(ascending=False))

fig, ax = plt.subplots(figsize=(12,6))

sns.barplot(
    data=industry_acceptance.reset_index(),
    x="offer_acceptance_rate",
    y="industry",
    color="teal",
    ax=ax
)

ax.set_title("Offer Acceptance Rate by Industry", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Offer Acceptance Rate (%)")
ax.set_ylabel("Industry")
ax.grid(axis="x", linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "06_recruitment" / "05_offer_acceptance_rate_by_industry.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 6: Salary vs Offer Acceptance Rate
#
# **Business Objective:** Analyze the relationship between salary and offer acceptance.

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="salary_usd",
    y="offer_acceptance_rate",
    alpha=0.45,
    s=35,
    color="crimson",
    ax=ax
)

ax.set_title("Salary vs Offer Acceptance Rate", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Salary (USD)")
ax.set_ylabel("Offer Acceptance Rate (%)")
ax.grid(linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()
plt.show()

# %% [markdown]
# # Chart 7: Interview Rounds vs Offer Acceptance Rate
#
# **Business Objective:** Analyze interview rounds versus offer acceptance.

# %%
fig, ax = plt.subplots(figsize=(10,6))

sns.scatterplot(
    data=df,
    x="interview_rounds",
    y="offer_acceptance_rate",
    alpha=0.45,
    s=35,
    color="darkorange",
    ax=ax
)

ax.set_title("Interview Rounds vs Offer Acceptance Rate", fontsize=16, fontweight="bold", pad=15)
ax.set_xlabel("Interview Rounds")
ax.set_ylabel("Offer Acceptance Rate (%)")
ax.grid(linestyle="--", alpha=0.3)
sns.despine()

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "06_recruitment" / "06_interview_rounds_vs_offer_acceptance_rate.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()

# %% [markdown]
# # Chart 8: Recruitment Correlation Matrix
#
# **Business Objective:** Understand relationships among recruitment metrics.

# %%
if "recruitment_success_index" not in df.columns:
    df["recruitment_success_index"]=(
        (
            df["offer_acceptance_rate"]+
            (100-df["hiring_difficulty_score"])+
            (100-(df["interview_rounds"]*10))
        )/3
    ).round(2)

if "candidate_attraction_score" not in df.columns:
    df["candidate_attraction_score"]=(
        (
            df["offer_acceptance_rate"]+
            df["salary_percentile"]+
            df["company_rating"]*20
        )/3
    ).round(2)

recruitment_corr=(
    df[[
        "offer_acceptance_rate",
        "salary_usd",
        "bonus_usd",
        "interview_rounds",
        "hiring_difficulty_score",
        "career_growth_score",
        "company_rating",
        "employee_satisfaction",
        "recruitment_success_index",
        "candidate_attraction_score"
    ]].corr()
)

fig, ax = plt.subplots(figsize=(10,8))

sns.heatmap(
    recruitment_corr,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5,
    square=True,
    cbar_kws={"shrink":0.8},
    ax=ax
)

ax.set_title("Recruitment Intelligence Correlation Matrix", fontsize=16, fontweight="bold", pad=15)

plt.tight_layout()

plt.savefig(
    VISUALIZATION_DIR / "06_recruitment" / "07_recruitment_correlation_matrix.png",
    dpi=300,
    bbox_inches="tight"
)

plt.show()
