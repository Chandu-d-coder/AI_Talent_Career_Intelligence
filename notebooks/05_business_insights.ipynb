# %% [markdown]
# # Module 1: Salary Intelligence - Business Findings
#
# This section summarizes the major business findings derived from the Salary Intelligence analysis of **90,000 AI workforce records**. It highlights the key compensation drivers, actionable business insights, strategic recommendations, and overall business value of the analysis.

# %% [markdown]
# # 1. Executive Summary
#
# The Salary Intelligence analysis of 90,000 AI workforce records reveals that compensation is primarily influenced by professional experience, geographic location, job role, and AI specialization. Salary growth follows a strong upward trend throughout an AI professional's career, with Lead-level professionals earning more than twice the compensation of Entry-level professionals. Mature AI markets consistently offer higher salaries, while specialized AI roles and advanced technical expertise command premium compensation. These insights support better workforce planning, compensation benchmarking, talent acquisition, and long-term career development.

# %% [markdown]
# # 2. Key Findings
#
# - Professional experience is the strongest driver of salary growth.
# - Lead-level professionals earn more than twice the salary of Entry-level professionals.
# - Mature AI markets such as the United States, Singapore, Canada, Australia, and the United Kingdom consistently offer higher compensation.
# - Research-oriented and advanced AI engineering roles command premium salaries.
# - AI specializations including LLMs, Generative AI, Computer Vision, MLOps, and Reinforcement Learning are among the highest-paying domains.
# - Salary differences become more significant at Senior and Lead experience levels.
# - Bonus compensation increases consistently with career progression.
# - Total compensation provides a more meaningful measure of employee rewards than base salary alone.

# %% [markdown]
# # 3. Business Insights
#
# - Professional experience contributes more to salary growth than educational qualifications alone.
# - Organizations should benchmark salaries against leading global AI markets to remain competitive.
# - High-demand AI specializations require premium compensation to attract skilled professionals.
# - Structured career progression improves employee retention and long-term workforce stability.
# - Competitive bonus programs strengthen overall compensation strategies and employee motivation.
# - Mature AI ecosystems continue to attract and retain highly skilled AI professionals.

# %% [markdown]
# # 4. Strategic Recommendations
#
# ## For Organizations
#
# - Establish structured salary progression aligned with career growth.
# - Benchmark compensation against global AI salary standards.
# - Invest in high-demand AI specializations to strengthen competitiveness.
# - Enhance bonus and incentive programs for experienced technical professionals.
# - Prioritize retention strategies for highly skilled AI talent.
#
# ## For AI Professionals
#
# - Build expertise in high-demand AI domains such as LLMs, Generative AI, MLOps, and Computer Vision.
# - Focus on continuous skill development and practical experience.
# - Evaluate career opportunities based on total compensation rather than base salary alone.
# - Consider global opportunities to maximize long-term career growth.

# %% [markdown]
# # 5. Business Impact
#
# This Salary Intelligence framework enables organizations to:
#
# - Benchmark compensation against industry standards.
# - Improve workforce planning and budgeting.
# - Design competitive salary structures.
# - Optimize recruitment investments.
# - Strengthen employee retention strategies.
# - Support data-driven compensation decisions.

# %% [markdown]
# # 6. Final Conclusion
#
# The Salary Intelligence analysis demonstrates that compensation in the AI workforce is influenced by multiple interconnected factors, including professional experience, job role, AI specialization, geographic location, and industry. Among these, professional experience remains the strongest predictor of salary growth. These findings provide valuable guidance for designing competitive compensation strategies, improving talent acquisition, and supporting long-term workforce planning. This module also establishes a strong analytical foundation for the remaining Workforce Analytics modules, including Career Growth, Workforce Risk, Talent Market, Employee Experience, and Recruitment Intelligence.

# %% [markdown]
# # Module 2: Career Growth Intelligence
#
# This section summarizes the key business findings, insights, and strategic recommendations derived from the Career Growth Intelligence analysis of **90,000 AI workforce records**.

# %% [markdown]
# # 1. Executive Summary
#
# The Career Growth Intelligence analysis evaluates how professional experience, promotion speed, salary percentile, AI specialization, job role, and geographic location influence long-term career progression in the AI workforce. Analysis of 90,000 AI professionals indicates that while overall career growth scores remain relatively consistent across demographic groups, promotion speed varies substantially with experience level. The engineered career metrics provide additional insights into career acceleration, momentum, and growth potential, enabling organizations to identify high-performing talent and optimize career development strategies.

# %% [markdown]
# # 2. Key Findings
#
# - The average **Career Growth Score** is **57.20**, with scores ranging from **25 to 99**.
# - The median Career Growth Score is **57**, indicating a balanced distribution of career growth opportunities.
# - **Promotion Speed** averages **38.44**, ranging from **12 to 98**, showing considerable variation in promotion timelines.
# - The average **Salary Percentile** is **50.54**, indicating a well-balanced salary distribution.
# - Career Growth Scores remain relatively stable across experience levels, while Promotion Speed consistently increases with seniority.
# - India records the highest average Career Growth Score, followed closely by the UAE, Singapore, and Brazil.
# - AI Engineer, Research Scientist, Computer Vision Engineer, NLP Engineer, and Data Scientist demonstrate strong career progression.
# - LLM and Generative AI specialists exhibit the highest career growth and promotion performance.
# - Career progression is influenced more by AI specialization and job role than by geographic location.
# - Engineered metrics such as Career Momentum Score, Growth Potential Index, and Career Acceleration Index provide deeper workforce intelligence than traditional KPIs alone.

# %% [markdown]
# # 3. Business Insights
#
# - Professional experience accelerates promotions but does not necessarily increase perceived career growth.
# - Promotion Speed is a stronger indicator of career progression than Career Growth Score alone.
# - High-demand AI domains such as LLMs and Generative AI provide stronger long-term career opportunities.
# - Career progression appears to depend more on specialization and role than on country.
# - Organizations should evaluate employee growth using multiple career metrics rather than a single KPI.
# - Engineered workforce metrics help identify high-potential employees who may otherwise be overlooked.
# - Employees with strong Career Momentum Scores represent valuable candidates for leadership development.

# %% [markdown]
# # 4. Strategic Recommendations
#
# ## For Organizations
#
# - Design structured promotion pathways based on demonstrated performance and technical expertise.
# - Prioritize retention of employees with high Career Momentum and Growth Potential.
# - Invest in emerging AI domains such as LLMs and Generative AI.
# - Incorporate engineered workforce metrics into talent review processes.
# - Regularly evaluate promotion fairness across roles, specializations, and countries.
# - Develop personalized career development plans based on employee growth potential.
#
# ## For AI Professionals
#
# - Build expertise in high-growth AI domains such as LLMs and Generative AI.
# - Continuously develop technical and professional skills.
# - Evaluate career opportunities based on long-term growth potential rather than salary alone.
# - Strengthen both technical depth and business understanding.
# - Track personal career momentum and invest in continuous learning.

# %% [markdown]
# # 5. Business Impact
#
# This Career Growth Intelligence framework enables organizations to:
#
# - Identify high-potential employees using advanced workforce metrics.
# - Improve succession planning and leadership development.
# - Design fair and transparent promotion strategies.
# - Optimize employee development initiatives.
# - Support data-driven talent management decisions.
# - Strengthen long-term workforce planning.

# %% [markdown]
# # 6. Final Conclusion
#
# The Career Growth Intelligence analysis demonstrates that career progression within the AI workforce is shaped by a combination of experience, technical specialization, promotion efficiency, and professional development. While Career Growth Scores remain relatively consistent across demographic groups, promotion speed and engineered workforce metrics provide deeper insights into long-term career success. These findings support more informed workforce planning, succession management, and employee development strategies while helping AI professionals identify effective pathways for sustained career advancement.

# %% [markdown]
# # Module 3: Workforce Risk Intelligence
#
# This section summarizes the key business findings, insights, and strategic recommendations derived from the Workforce Risk Intelligence analysis of **90,000 AI workforce records**.

# %% [markdown]
# # 1. Executive Summary
#
# The Workforce Risk Intelligence analysis evaluates workforce stability by examining job security, layoff risk, automation risk, and AI adoption across the global AI workforce. The results indicate that senior professionals consistently experience stronger job security and lower layoff risk than entry-level employees. While automation risk remains relatively similar across AI job roles, workforce stability is primarily influenced by job security and organizational resilience rather than automation alone. The engineered workforce metrics provide a comprehensive framework for identifying resilient talent and supporting strategic workforce planning.

# %% [markdown]
# # 2. Key Findings
#
# - The average **Job Security Score** is **75.56**, indicating generally stable employment across the AI workforce.
# - The average **Layoff Risk** is **0.18**, suggesting a relatively low probability of workforce reductions.
# - The average **Automation Risk** is **50.36**, representing moderate automation exposure across AI roles.
# - The average **AI Adoption Score** is **71.38**, reflecting strong AI implementation across industries.
# - Senior and Lead professionals exhibit the highest job security, while Entry-level professionals experience the highest layoff risk.
# - UAE records the highest average Job Security Score, followed by Australia and Japan.
# - Data Scientist, AI Software Engineer, Research Scientist, NLP Engineer, and AI Engineer demonstrate the strongest workforce stability.
# - Technology leads in Job Security, while Automotive records the highest AI Adoption Score.
# - Layoff Risk has the strongest negative relationship with Job Security, whereas Automation Risk has comparatively little direct influence.
# - Engineered metrics such as Workforce Stability Index, Automation Resilience Score, Risk Exposure Index, and AI Workforce Readiness Score provide deeper workforce intelligence than traditional KPIs.

# %% [markdown]
# # 3. Business Insights
#
# - Professional experience is the strongest contributor to workforce stability.
# - Layoff Risk is the primary factor influencing Job Security.
# - AI adoption alone does not guarantee higher workforce stability.
# - Higher employee satisfaction is associated with stronger workforce resilience and retention.
# - Technology-driven industries successfully balance AI adoption with workforce stability.
# - Engineered workforce metrics provide a more comprehensive view of workforce health than individual KPIs.
# - Organizations should evaluate workforce resilience using multiple indicators rather than relying solely on layoff probability.

# %% [markdown]
# # 4. Strategic Recommendations
#
# ## For Organizations
#
# - Prioritize retention strategies for Entry-level professionals.
# - Develop structured career progression pathways.
# - Continuously monitor Layoff Risk as a workforce health indicator.
# - Integrate AI adoption initiatives with employee reskilling programs.
# - Use Workforce Stability Index and AI Workforce Readiness Score during workforce planning.
# - Strengthen employee engagement and satisfaction initiatives.
#
# ## For AI Professionals
#
# - Build specialized technical expertise to strengthen long-term job security.
# - Continuously update AI skills to remain resilient against automation.
# - Target organizations with strong AI adoption and stable workforce practices.
# - Invest in professional development to improve long-term career stability.
# - Evaluate career opportunities using overall workforce stability rather than salary alone.

# %% [markdown]
# # 5. Business Impact
#
# This Workforce Risk Intelligence framework enables organizations to:
#
# - Identify workforce vulnerability and resilience.
# - Improve workforce planning and succession management.
# - Strengthen employee retention strategies.
# - Support AI-driven workforce transformation.
# - Optimize organizational risk management.
# - Enable data-driven workforce decision-making.

# %% [markdown]
# # 6. Final Conclusion
#
# The Workforce Risk Intelligence analysis demonstrates that workforce stability within the AI industry is primarily driven by professional experience, job security, and organizational workforce practices. Although automation continues to reshape the AI labor market, its direct impact on job security remains limited compared with layoff risk and employee development. These insights enable organizations to strengthen workforce resilience, improve talent retention, and make informed strategic workforce decisions while helping AI professionals identify sustainable long-term career opportunities.

# %% [markdown]
# # Module 4: Talent Market Intelligence
#
# This section summarizes the key business findings, insights, and strategic recommendations derived from the Talent Market Intelligence analysis of **90,000 AI job records**.

# %% [markdown]
# # 1. Executive Summary
#
# The Talent Market Intelligence analysis evaluates hiring demand, skill demand, recruitment competitiveness, and market opportunities across the global AI workforce. Based on **90,000 AI job records**, the analysis shows that AI hiring demand remains consistently strong across countries and industries, while specialized AI skills continue to drive recruitment competitiveness. Engineered market indicators further highlight high-opportunity markets, premium AI skills, and recruitment efficiency, providing organizations with actionable insights for workforce planning and talent acquisition.

# %% [markdown]
# # 2. Key Findings
#
# - The dataset contains **90,000 AI job records**, providing a comprehensive view of the AI hiring landscape.
# - Average **Job Openings** are **17.52**, ranging from **1 to 50** positions.
# - The average **Skill Demand Score** is **50.46**, indicating balanced demand across AI competencies.
# - **Hiring Difficulty** averages **55.03**, reflecting moderate competition for AI talent.
# - Organizations conduct an average of **4.5 interview rounds** during AI recruitment.
# - The **USA** records the highest average job openings, followed by the **UK, Singapore, Japan, and Australia**.
# - **AI Software Engineer** has the highest average job openings, while **NLP Engineer** records the highest Hiring Difficulty Score.
# - **Reinforcement Learning**, **LLMs**, **Generative AI**, **Analytics**, and **MLOps** demonstrate consistently strong market demand.
# - **Healthcare**, **Technology**, and **Finance** remain among the strongest industries for AI hiring.
# - Engineered metrics such as **Talent Demand Index**, **Market Opportunity Index**, **Hiring Efficiency Score**, and **Skill Premium Index** provide deeper talent market intelligence than traditional hiring metrics.

# %% [markdown]
# # 3. Business Insights
#
# - Global demand for AI professionals remains consistently strong across countries and industries.
# - Specialized AI skills provide greater recruitment advantages than geographic location.
# - LLMs, NLP, Reinforcement Learning, and Generative AI continue to represent highly competitive talent markets.
# - Organizations recruiting specialized AI talent should expect higher hiring difficulty and longer recruitment cycles.
# - AI hiring demand is broadly distributed across industries, demonstrating widespread enterprise AI adoption.
# - Engineered market metrics provide a more comprehensive assessment of hiring demand than individual recruitment KPIs.
# - Workforce planning should prioritize strategic skill development alongside hiring expansion.

# %% [markdown]
# # 4. Strategic Recommendations
#
# ## For Organizations
#
# - Prioritize hiring in high-demand AI domains such as LLMs, NLP, Reinforcement Learning, and Generative AI.
# - Develop proactive talent pipelines to reduce hiring difficulty.
# - Invest in internal upskilling programs to address emerging skill shortages.
# - Monitor Talent Demand Index and Market Opportunity Index during workforce planning.
# - Optimize recruitment processes to improve hiring efficiency while maintaining candidate quality.
# - Benchmark hiring strategies against mature AI markets.
#
# ## For AI Professionals
#
# - Develop expertise in high-demand AI specializations.
# - Build practical project experience alongside technical skills.
# - Target industries with sustained AI hiring demand, including Healthcare, Technology, and Finance.
# - Prepare for multi-stage interview processes.
# - Continuously update technical skills to remain competitive.

# %% [markdown]
# # 5. Business Impact
#
# This Talent Market Intelligence framework enables organizations to:
#
# - Identify high-demand AI roles and specializations.
# - Improve talent acquisition strategies.
# - Optimize workforce planning.
# - Benchmark recruitment competitiveness.
# - Strengthen hiring pipelines.
# - Support data-driven hiring and workforce decisions.

# %% [markdown]
# # 6. Final Conclusion
#
# The Talent Market Intelligence analysis demonstrates that the global AI employment market remains highly active, with consistently strong hiring demand across countries, industries, and technical domains. Although recruitment demand is broadly distributed, specialized AI skills substantially increase employability and recruitment competitiveness. These insights help organizations optimize talent acquisition and workforce planning while enabling AI professionals to identify high-opportunity career paths and future-proof their technical expertise.

# %% [markdown]
# # Module 5: Employee Experience Intelligence
#
# This notebook summarizes the major business findings, insights, and recommendations from the **Employee Experience Intelligence** analysis conducted on **90,000 AI workforce records**.

# %% [markdown]
# # 1. Executive Summary
#
# The Employee Experience Intelligence analysis evaluates employee satisfaction, work-life balance, working hours, vacation policies, and company ratings across the global AI workforce. The results indicate that employee satisfaction is generally high across the dataset, with salary, job security, and work-life balance emerging as the strongest contributors to a positive employee experience. Work mode has only a marginal impact, suggesting that overall organizational practices matter more than whether employees work remotely, onsite, or in a hybrid environment.

# %% [markdown]
# # 2. Key Findings
#
# ## Employee Experience Overview
#
# - Average **Employee Satisfaction**: **72.73**
# - Average **Work-Life Balance Score**: **69.15**
# - Average **Weekly Working Hours**: **45.48**
# - Average **Company Rating**: **4.00 / 5**
# - Average **Vacation Days**: **20**
#
# ## Work Mode Intelligence
#
# - Employee Satisfaction remains nearly identical across Hybrid, Onsite, and Remote work models.
# - Remote employees record the highest average Work-Life Balance Score.
# - Work mode alone has minimal influence on employee satisfaction.
#
# ## Country Intelligence
#
# - USA records the highest Employee Satisfaction, followed by Singapore and Australia.
# - India and Brazil report comparatively lower satisfaction scores.
#
# ## Industry Intelligence
#
# - Employee Satisfaction remains highly consistent across industries.
# - Retail and Technology report the highest average satisfaction.
#
# ## Relationship Intelligence
#
# - Salary has the strongest positive relationship with Employee Satisfaction.
# - Job Security and Work-Life Balance also show positive relationships.
# - Weekly Working Hours demonstrate a moderate negative relationship with satisfaction.
# - Company Rating and Vacation Days have relatively weak direct relationships.
#
# ## Engineered Employee Experience Metrics
#
# - Average **Employee Experience Index**: **73.95**
# - Average **Wellbeing Score**: **65.47**
# - Top-performing employees achieve Employee Experience Index values above **95**.

# %% [markdown]
# # 3. Business Insights
#
# - Competitive compensation remains the strongest driver of employee satisfaction.
# - Strong job security improves employee morale and long-term engagement.
# - Healthy work-life balance contributes significantly to employee wellbeing.
# - Longer working hours reduce employee satisfaction.
# - Flexible work arrangements alone are insufficient without supportive organizational policies.
# - Employee Experience Index provides a comprehensive measure of workforce wellbeing.
# - Organizations should evaluate employee wellbeing using multiple performance indicators rather than a single KPI.

# %% [markdown]
# # 4. Strategic Recommendations
#
# ## For Organizations
#
# - Maintain competitive compensation strategies.
# - Reduce excessive workloads through balanced resource planning.
# - Strengthen employee wellbeing initiatives.
# - Improve job security through transparent communication and career development.
# - Monitor Employee Experience Index and Wellbeing Score regularly.
# - Invest in employee engagement and workplace culture.
#
# ## For AI Professionals
#
# - Evaluate employers based on overall employee experience instead of salary alone.
# - Prioritize organizations with strong job security and work-life balance.
# - Monitor workload to maintain long-term wellbeing.
# - Consider company culture when making career decisions.
# - Invest in continuous professional development.

# %% [markdown]
# # 5. Business Impact
#
# This Employee Experience Intelligence framework enables organizations to:
#
# - Improve employee satisfaction.
# - Strengthen workforce retention.
# - Monitor employee wellbeing.
# - Support data-driven HR decisions.
# - Enhance workplace productivity.
# - Benchmark organizational employee experience.

# %% [markdown]
# # 6. Final Conclusion
#
# The Employee Experience Intelligence analysis demonstrates that employee satisfaction is influenced primarily by compensation, job security, work-life balance, and workload rather than work mode alone. Organizations that combine competitive salaries, stable employment, and healthy workplace practices create stronger employee experiences and improve long-term workforce retention. The engineered employee experience metrics provide practical tools for measuring organizational wellbeing and supporting data-driven human resource strategies.

# %% [markdown]
# # Module 6: Recruitment Intelligence

# %% [markdown]
# ## Executive Summary
#
# The Recruitment Intelligence analysis evaluates offer acceptance, hiring difficulty, interview process efficiency, and candidate attraction across the global AI workforce. Analysis of **90,000 AI recruitment records** indicates that offer acceptance rates remain consistently high across countries, industries, and AI specializations. Unlike other workforce metrics, recruitment success is influenced by multiple organizational and market factors rather than any single variable. The engineered recruitment metrics provide a practical framework for measuring recruitment effectiveness and improving hiring strategies.

# %% [markdown]
# ## Key Findings
#
# ### Recruitment Overview
# - The average **Offer Acceptance Rate** is **75.01%**, indicating a strong overall recruitment success rate.
# - Organizations conduct an average of **4.5 interview rounds** per recruitment process.
# - The average **Hiring Difficulty Score** is **55.03**, suggesting moderate recruitment competition across AI roles.
# - Offer acceptance ranges from **55% to 95%**, indicating substantial variation among candidates.
#
# ### Country Intelligence
# - France (75.33%) records the highest average Offer Acceptance Rate.
# - Canada (75.13%), UK (75.06%), and Germany (75.05%) also demonstrate strong recruitment success.
# - Differences across countries are minimal, indicating globally consistent candidate acceptance behavior.
#
# ### Job Role Intelligence
# - Data Analyst (75.19%) records the highest Offer Acceptance Rate.
# - Machine Learning Engineer, Data Scientist, Computer Vision Engineer, and Research Scientist maintain similarly high acceptance levels.
# - Recruitment success remains relatively consistent across AI job roles.
#
# ### AI Specialization Intelligence
# - LLM specialists (75.21%) achieve the highest Offer Acceptance Rate.
# - NLP, Analytics, and MLOps also maintain consistently high candidate acceptance.
# - Offer acceptance varies only slightly between AI specializations, suggesting broad market attractiveness.
#
# ### Industry Intelligence
# - Retail (75.11%) and Finance (75.09%) record the highest Offer Acceptance Rates.
# - Telecom, Education, and Energy industries closely follow.
# - Industry has only a limited impact on recruitment outcomes.
#
# ### Recruitment Relationship Intelligence
# - Offer Acceptance Rate shows almost no meaningful correlation with Salary, Bonus, Career Growth, Company Rating, or Employee Satisfaction.
# - Hiring Difficulty demonstrates a very weak negative relationship (-0.01) with Offer Acceptance.
# - Candidate acceptance decisions appear to be influenced by multiple qualitative factors beyond traditional recruitment KPIs.
#
# ### Engineered Recruitment Metrics
# - Average Recruitment Success Index: **58.34**
# - Average Candidate Attraction Score: **68.50**
# - Top-performing recruitment records achieve Recruitment Success Index values above **91**, indicating exceptionally efficient recruitment processes.

# %% [markdown]
# ## Business Insights
#
# - AI recruitment remains healthy, with consistently high offer acceptance across the global market.
# - Salary alone is not a reliable predictor of candidate acceptance in this dataset.
# - Organizations with streamlined recruitment processes can improve recruitment efficiency without significantly affecting acceptance rates.
# - Candidate decisions appear to depend on a combination of organizational reputation, career opportunities, and overall employee value proposition.
# - LLM and emerging AI specializations continue to attract strong candidate interest.
# - Engineered recruitment metrics provide a more comprehensive assessment of recruitment performance than offer acceptance alone.
# - Recruitment effectiveness should be evaluated using a balanced combination of hiring efficiency, candidate attraction, and process quality.

# %% [markdown]
# ## Strategic Recommendations
#
# ### For Organizations
# - Focus on improving the overall candidate experience rather than relying solely on salary increases.
# - Simplify recruitment workflows to reduce unnecessary interview stages.
# - Monitor Recruitment Success Index and Candidate Attraction Score to evaluate hiring performance.
# - Strengthen employer branding to improve long-term recruitment competitiveness.
# - Build specialized recruitment pipelines for high-demand AI domains such as LLMs, NLP, and MLOps.
# - Continuously review recruitment performance using data-driven hiring metrics.
#
# ### For AI Professionals
# - Evaluate employers based on career growth opportunities and organizational quality in addition to compensation.
# - Prepare for multi-stage recruitment processes commonly used in AI hiring.
# - Build expertise in high-demand AI specializations to improve recruitment success.
# - Strengthen technical portfolios and project experience to increase employer attractiveness.
# - Develop both technical and communication skills to improve interview performance.

# %% [markdown]
# ## Conclusion
#
# The Recruitment Intelligence analysis demonstrates that AI recruitment remains highly competitive yet consistently successful across global markets. Offer acceptance is influenced by a combination of organizational practices, candidate expectations, and overall employer attractiveness rather than salary alone. By leveraging engineered recruitment metrics and optimizing hiring strategies, organizations can improve recruitment efficiency while attracting and retaining high-quality AI talent.
