# %%
# Import Libraries

import pandas as pd
import numpy as np

# Configure Display Settings

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", 100)
pd.set_option("display.width", None)

# Display Environment Information

print("\nEnvironment Information")
print("-" * 22)

print(f"Pandas Version : {pd.__version__}")
print(f"NumPy Version  : {np.__version__}")

# %% [markdown]
# ### Phase 3 - Mission 1
# ### Intelligence Opportunity Discovery

# %%
df = pd.read_csv("../data/processed/cleaned_ai_jobs.csv")

print("-" * 28)
print("Dataset loaded successfully")
print("-" * 28)

df.head()

# %%
# df.info()
df.describe().T
df.columns
# Out:
# Index(['id', 'country', 'job_role', 'ai_specialization', 'experience_level',
#        'experience_years', 'salary_usd', 'bonus_usd', 'education_required',
#        'industry', 'company_size', 'interview_rounds', 'year', 'work_mode',
#        'weekly_hours', 'company_rating', 'job_openings',
#        'hiring_difficulty_score', 'layoff_risk', 'ai_adoption_score',
#        'company_funding_billion', 'economic_index', 'ai_maturity_years',
#        'offer_acceptance_rate', 'tax_rate_percent', 'vacation_days',
#        'skill_demand_score', 'automation_risk', 'job_security_score',
#        'career_growth_score', 'work_life_balance_score', 'promotion_speed',
#        'salary_percentile', 'cost_of_living_index', 'employee_satisfaction'],
#       dtype='str')

# %% [markdown]
# ### Phase 3 - Mission 1
# ### Intelligence Opportunity Discovery
#
# Category 1: Salary Intelligence
#
# Questions:
#
# - Does country affect salary?
# - Does experience affect salary?
# - Does hiring difficulty affect salary?
# - Does number of interview rounds affect salary?
# - Does industry affect salary?
#
# Category 2: Career Growth Intelligence
#
# Questions:
#
# - Does skill demand improve career growth?
# - What affects career growth most?
# - Does AI specialization impact promotion speed?
# - Does experience influence promotion speed?
#
# Category 3: Workforce Risk Intelligence
#
# Questions:
#
# - Does AI adoption affect job security?
# - Does layoff risk vary by country?
# - Does company behavior affect job security?
# - Which jobs are safest?
#
# Category 4: Talent Market Intelligence
#
# Questions:
#
# - What affects job openings?
# - Which factors increase hiring demand?
# - Why are some skills more demanded?
#
# Category 5: Employee Experience Intelligence
#
# Questions:
#
# - Does work mode affect work-life balance?
# - Does company rating affect satisfaction?
# - What improves employee happiness?
#
# Category 6: Recruitment Intelligence 🎯
#
# Questions:
#
# - Why do candidates reject offers?
# - Is salary the main reason?
# - Does hiring difficulty impact acceptance?

# %% [markdown]
# ### Mission 2
# ### Outcome Variables & Influencing Factors
#
# Salary
#
# - country
# - job_role
# - ai_specialization
# - experience_level
# - experience_years
# - education_required
# - hiring_difficulty_score
#
# Career Growth
#
# - promotion_speed
# - career_growth_score
# - salary_percentile
# - experience_years
# - country
# - job_role
#
# Job Security
#
# - layoff_risk
# - ai_adoption_score
# - automation_risk
# - job_security_score
#
# Work-Life Balance
#
# - work_life_balance_score
# - work_mode
# - vacation_days
# - weekly_hours
#
# Offer Acceptance Rate
#
# - country
# - job_role
# - salary_usd
# - offer_acceptance_rate
#
# Job Openings
#
# -
